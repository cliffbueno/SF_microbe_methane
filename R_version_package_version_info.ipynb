# %% [markdown]
# # R version & package version
# - code tested in this environment
# - this is a "base" install which likely includes many extra packages

# %%
R.Version()
# Out:
# $platform
# [1] "x86_64-apple-darwin13.4.0"
#
# $arch
# [1] "x86_64"
#
# $os
# [1] "darwin13.4.0"
#
# $system
# [1] "x86_64, darwin13.4.0"
#
# $status
# [1] ""
#
# $major
# [1] "4"
#
# $minor
# [1] "0.2"
#
# $year
# [1] "2020"
#
# $month
# [1] "06"
#
# $day
# [1] "22"
#
# $`svn rev`
# [1] "78730"
#
# $language
# [1] "R"
#
# $version.string
# [1] "R version 4.0.2 (2020-06-22)"
#
# $nickname
# [1] "Taking Off Again"

# %%
pkgs = installed.packages()

# %%
options(repr.matrix.max.cols=13, repr.matrix.max.rows=600)
pkgs
# Out:
#                      Package              LibPath
# abind                abind                /anaconda/envs/R_4.0/lib/R/library
# acepack              acepack              /anaconda/envs/R_4.0/lib/R/library
# ade4                 ade4                 /anaconda/envs/R_4.0/lib/R/library
# ade4TkGUI            ade4TkGUI            /anaconda/envs/R_4.0/lib/R/library
# adegraphics          adegraphics          /anaconda/envs/R_4.0/lib/R/library
# affy                 affy                 /anaconda/envs/R_4.0/lib/R/library
# affyio               affyio               /anaconda/envs/R_4.0/lib/R/library
# AICcmodavg           AICcmodavg           /anaconda/envs/R_4.0/lib/R/library
# akima                akima                /anaconda/envs/R_4.0/lib/R/library
# amap                 amap                 /anaconda/envs/R_4.0/lib/R/library
# annotate             annotate             /anaconda/envs/R_4.0/lib/R/library
# AnnotationDbi        AnnotationDbi        /anaconda/envs/R_4.0/lib/R/library
# ...
