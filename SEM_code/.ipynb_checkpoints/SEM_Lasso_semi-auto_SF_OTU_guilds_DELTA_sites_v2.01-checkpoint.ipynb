# %% [markdown]
# # SEM - Lasso semi-auto for SF OTU guilds v2.0
#
# - forks from "SEM - Lasso semi-auto for SF OTU guilds v1.12.ipynb"
# - intent is to DECREASE run/load times with external modules (from 30-60 min to set up )

# %%
library(tibble)
`%notin%` <- Negate(`%in%`)

# %%
setwd('~/Documents/GitHub/SF_microbe_methane/SEM_code/')

# %% [markdown]
# # 1) load R libraries, own lasSEM modules / functions, data

# %% [markdown]
# - TODO:
# - need to clean new modules below, especially example data (and redundancies)
# - note some misplaced package loading within modules
# - and some setwd's likely to make problems
#
#
# - Also need to extract many definitions from that code (colors, variable & composite lists, SEM feats)
# - move to 2) below

# %%
# load packages, earlier R modules
source('lasSEM_R_modules/lasSEM_0_import_modules_v1.12.R') # -- this has a wd reset in it!
setwd('~/Documents/GitHub/SF_microbe_methane/SEM_code/')

# %%
# load data, SHOULD BE SIMPLIFIED or R.data
# - note flat files were written, still contains many defs
# suppressWarnings(source('lasSEM_R_modules/lasSEM_1_2_import_data_guilds_meta_v1.12.R'))
# Don't need this because already saved the files needed
# Data (all and Delta only)
Guild_CH4 <- read.table("~/Documents/GitHub/SF_microbe_methane/data/SEM_data/SEM_base_log2_10_all_guild_soil_data.txt")
dim(Guild_CH4)
head(Guild_CH4)

Guild_CH4_d <- read.table("~/Documents/GitHub/SF_microbe_methane/data/SEM_data/SEM_base_log2_10_delta_guild_soil_data.txt")
dim(Guild_CH4_d)
head(Guild_CH4_d)
# Out:
# [1] 152  51
#   Sample             CH4_ug_m2_h CH4_logn1 CO2_mg_m2_h CH4_CO2   Bulk_dens
# 1 Browns_ThreeSqA_D1 0.472344434 0.5218678 1.05517851  -1.582834 -0.4475316
# 2 Browns_ThreeSqA_D2 0.472344434 0.5218678 1.05517851  -1.582834 -0.4304467
# 3 Browns_ThreeSqB_D1 0.005190917 0.1368549 0.56450338  -1.559312 -0.4583895
# 4 Browns_ThreeSqB_D2 0.005190917 0.1368549 0.56450338  -1.559312 -0.3957837
# 7 Browns_TuleA_D2    0.038122722 0.1614124 0.03842647  -1.000304 -0.3031784
# 8 Browns_TuleB_D1    0.267422593 0.3442878 0.43166113  -1.164239 -0.4105685
#   H2O_FPS  pH        C         N          ⋯ Actino   Chlorf   Firmic
# 1 1.871870 0.7958800 0.9127533 -0.2225732 ⋯ 14.71778 15.35749 12.03718
# 2 1.863437 0.7817554 0.8561244 -0.3010300 ⋯ 14.69337 15.54305 13.06765
# 3 1.876980 0.7944880 0.9227255 -0.2276783 ⋯ 14.94039 15.21020 11.94527
# 4 1.844697 0.7730547 0.8082110 -0.3381873 ⋯ 13.90484 15.60783 11.73935
# 7 1.842354 0.7589119 0.7315888 -0.4100504 ⋯ 14.94913 15.50704 13.57540
# 8 1.864015 0.7817554 0.8591383 -0.2806687 ⋯ 13.98774 15.13678 10.42214
#   AO_NOB      NOB_AO      mcr_pmo   pmo_mcr  CH4_all   CH4_ac_mix MOB_all
# 1  0.84482076 -0.84482076 -7.514671 7.514671  8.781141 7.927983   15.01202
# 2  0.14351626 -0.14351626 -6.797039 6.797039 10.377120 9.275425   16.22609
# 3  0.90191500 -0.90191500 -8.156083 8.156083  7.841561 6.998851   14.98501
# 4 -0.09574985  0.09574985 -7.037079 7.037079  9.102746 7.576630   15.48129
# 7 -0.06451276  0.06451276 -6.886575 6.886575  9.626566 8.506827   15.57561
# 8  0.75954597 -0.75954597 -9.528989 9.528989  5.433031 4.673630   13.67311
# [1] 65 51
#   Sample             CH4_ug_m2_h CH4_logn1 CO2_mg_m2_h CH4_CO2   Bulk_dens
# 1 Browns_ThreeSqA_D1 0.472344434 0.5218678 1.05517851  -1.582834 -0.4475316
# 2 Browns_ThreeSqA_D2 0.472344434 0.5218678 1.05517851  -1.582834 -0.4304467
# 3 Browns_ThreeSqB_D1 0.005190917 0.1368549 0.56450338  -1.559312 -0.4583895
# 4 Browns_ThreeSqB_D2 0.005190917 0.1368549 0.56450338  -1.559312 -0.3957837
# 5 Browns_TuleA_D2    0.038122722 0.1614124 0.03842647  -1.000304 -0.3031784
# 6 Browns_TuleB_D1    0.267422593 0.3442878 0.43166113  -1.164239 -0.4105685
#   H2O_FPS  pH        C         N          ⋯ Actino   Chlorf   Firmic
# 1 1.871870 0.7958800 0.9127533 -0.2225732 ⋯ 14.71778 15.35749 12.03718
# 2 1.863437 0.7817554 0.8561244 -0.3010300 ⋯ 14.69337 15.54305 13.06765
# 3 1.876980 0.7944880 0.9227255 -0.2276783 ⋯ 14.94039 15.21020 11.94527
# 4 1.844697 0.7730547 0.8082110 -0.3381873 ⋯ 13.90484 15.60783 11.73935
# 5 1.842354 0.7589119 0.7315888 -0.4100504 ⋯ 14.94913 15.50704 13.57540
# 6 1.864015 0.7817554 0.8591383 -0.2806687 ⋯ 13.98774 15.13678 10.42214
#   AO_NOB      NOB_AO      mcr_pmo   pmo_mcr  CH4_all   CH4_ac_mix MOB_all
# 1  0.84482076 -0.84482076 -7.514671 7.514671  8.781141 7.927983   15.01202
# 2  0.14351626 -0.14351626 -6.797039 6.797039 10.377120 9.275425   16.22609
# 3  0.90191500 -0.90191500 -8.156083 8.156083  7.841561 6.998851   14.98501
# 4 -0.09574985  0.09574985 -7.037079 7.037079  9.102746 7.576630   15.48129
# 5 -0.06451276  0.06451276 -6.886575 6.886575  9.626566 8.506827   15.57561
# 6  0.75954597 -0.75954597 -9.528989 9.528989  5.433031 4.673630   13.67311

# %%
# Updated define_new_sem_table function
suppressWarnings(source('lasSEM_R_modules/lasSEM_3_SEM_basics_MI_COV_v1.12.R'))
# Out:
# [1] "ran SEM to create models: sem.ch4_mod0, sem.ch4_mod0a.1"
# [1] "ran SEM to create models: sem.ch4_mod0, sem.ch4_mod0a.1"
# Plot with title “”

# %%
source('lasSEM_R_modules/lasSEM_4_SEM_basics_example_v1.12.R')

# %%
# Colors
library(rlang)
Guild_cols <- read.table("~/Documents/GitHub/SF_microbe_methane/data/colors/Guild_color_palette.txt", sep='\t') %>%
  dplyr::select(Guild, G_index, color) %>%
  set_names(c("Guild", "Index", "color")) %>%
  mutate(Index = rev(Index)) %>%
  add_row(Guild = "CH4_me", Index = 16, color = "#FDC086") %>%
  add_row(Guild = "CH4_mix", Index = 17, color = "#FFFF99") %>%
  arrange(Index)
Guild_cols
guild_colors <- Guild_cols
# Out:
#       Guild   Index color
# 15    FeRB     1    #8B4513
# 14    FeOB     2    #CD6600
# 13    SRB      3    #8B008B
# 12    SRB_syn  4    #CD2990
# 11    SOxB     5    #CD69C9
# 10    Anamx    6    #00FF7F
# 9     NOB      7    #008B00
# 8     AOB      8    #00CD00
# 7     AOA      9    #7CFC00
# 6     MeOB    10    #836FFF
# 5     MOB_IIa 11    #36648B
# 4     MOB_II  12    #4F94CD
# 3     MOB_I   13    #63B8FF
# 2     CH4_ac  14    #8B3626
# 1     CH4_H2  15    #CD4F39
# ...16 CH4_me  16    #FDC086
# ...17 CH4_mix 17    #FFFF99

# %%
# Troubleshoot - look at code in the module
y_var <- 'CH4_logn1'
x_vars <- xvars1
Guild_CH4_dS <- scale(Guild_CH4_d[,-1])              #  careful will scale y 
Guild_CH4_dS_df <- data.frame(Guild_CH4_dS)          #  make df
Guild_CH4_dS_df$CH4_logn1 <- Guild_CH4_d0$CH4_logn1  # fix CH4 scale to original
CH4_lass0 <- glmnet_lassoCV(y_var, x_vars, Guild_CH4_d0)
vars <- glmnet_coefs(CH4_lass0, output = 'vars')      # return only list of signif vars
vars
names(guild_colors)[1] <- "var"
CH4_lass0_cplot <- plot_lasso_coefs(CH4_lass0, guild_colors)
options(repr.plot.width=6, repr.plot.height=4)
CH4_lass0_cplot
subs <- all_subsets_whhP('CH4_logn1', vars, Guild_CH4_dS_df, p_cut = 0.05, sort = "AIC", ncores = 20)
# dim(subs); 
subs[1:20,]  # show output
# Out:
# [1] "best_lambda: 0.041"
#      R2  RMSE
# 1 0.862 0.398
#  [1] "CO2_mg_m2_h" "Bulk_dens"   "H2O_FPS"     "pH"          "CH4_ac"
#  [6] "CH4_me"      "MOB_IIa"     "ANME"        "AOB"         "CH4_ac_mix"
#     n_pred AIC      BIC       AICc
# 700 7      77.24463  94.63973 79.81606
# 429 6      78.24550  93.46621 80.21042
# 439 6      79.93356  95.15427 81.89847
# 191 5      80.86829  93.91461 82.31656
# 420 6      82.15703  97.37774 84.12194
# 201 5      82.72998  95.77630 84.17826
# 432 6      83.48311  98.70382 85.44802
# 257 5      83.94050  96.98683 85.38878
# 244 5      85.24353  98.28986 86.69181
# 418 6      85.64768 100.86839 87.61259
# 89  4      85.65708  96.52901 86.67403
# 428 6      85.75791 100.97863 87.72283
# 250 5      86.38923  99.43556 87.83751
# 413 6      86.48681 101.70752 88.45172
# 422 6      86.84585 102.06657 88.81077
# 202 5      86.88462  99.93095 88.33290
# 200 5      88.11632 101.16264 89.56459
# 433 6      88.19778 103.41849 90.16269
# 79  4      88.50749  99.37942 89.52443
# 238 5      88.69547 101.74180 90.14375
#     model
# 700 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + MOB_IIa + ANME + CH4_ac_mix
# 429 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME + AOB
# 439 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + MOB_IIa + ANME + CH4_ac_mix
# 191 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME
# 420 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + pH + ANME + CH4_ac_mix
# 201 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + ANME + AOB
# 432 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_me + MOB_IIa + ANME
# 257 CH4_logn1  ~  CO2_mg_m2_h + MOB_IIa + ANME + CH4_ac_mix
# 244 CH4_logn1  ~  CO2_mg_m2_h + CH4_ac + MOB_IIa + ANME
# 418 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + pH + MOB_IIa + CH4_ac_mix
# 89  CH4_logn1  ~  CO2_mg_m2_h + ANME + AOB
# 428 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + MOB_IIa + CH4_ac_mix
# 250 CH4_logn1  ~  CO2_mg_m2_h + CH4_me + MOB_IIa + ANME
# 413 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + pH + CH4_me + ANME
# 422 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + CH4_me + MOB_IIa
# 202 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + ANME + CH4_ac_mix
# 200 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + MOB_IIa + CH4_ac_mix
# 433 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_me + MOB_IIa + AOB
# 79  CH4_logn1  ~  CO2_mg_m2_h + CH4_ac + ANME
# 238 CH4_logn1  ~  CO2_mg_m2_h + pH + ANME + CH4_ac_mix
#     all_sig
# 700 yes
# 429 yes
# 439 yes
# 191 yes
# 420 yes
# 201 yes
# 432 yes
# 257 yes
# 244 yes
# 418 yes
# 89  yes
# 428 yes
# 250 yes
# 413 yes
# 422 yes
# 202 yes
# 200 yes
# 433 yes
# 79  yes
# 238 yes
# plot without title

# %%
# Note, no MeOB
guild_vars <- Guild_cols %>%
    filter(Guild != "MeOB")

# %% [markdown]
# ### Figure S10

# %%
# plot_lasso_coefs plot code
names(guild_colors)[1] <- "var"
plot_lasso_coefs = function(model_out, colors, nafill = '#708090'){

    # dev lasso effects plot
    coefs <- glmnet_coefs(model_out)              # Get significant effects

    # merge w colors
    coef_color <- data.frame(merge(coefs, colors, all.x=T, by = 'var'))     # coef_color
    colors2 <- as.character(coef_color$color)                               # only levels of var used  
    colors2[is.na(colors2)] <- '#708090'                                    # replace NA color 
    coef_color$color <- as.factor(colors2)                                  # replace colors (levels)
                         
    # reorder data / factors by coef
    coef_color <- coef_color[order(coef_color$coef, decreasing = TRUE),]                       # sort by coef
    coef_color$var <- reorder(coef_color$var, -coef_color$coef)              # reorder var by coef
    coef_color$color <- reorder(coef_color$color, -coef_color$coef)          # reorder color by coef

    # Make ggplot 
    plot_colors <- c(paste(coef_color$color))                               # Get colors for ggplot

    plot <- ggplot(data=coef_color, 
                   aes(x=var, y=coef, fill = var)) +       # base plot
                geom_bar(stat="identity") + 
                scale_fill_manual(values= plot_colors) +  # fill by 
                #geom_hline(yintercept=0) +                                            # add y = 0 line
                coord_flip() + 
                theme_minimal() + 
                theme(legend.position = "none")       # flip; clean plot

    return(plot)
}

# %% [markdown]
# ## Figure 10a

# %%
# Need to get this plot for guilds only, and then the genera in those guilds (Figure S10)
y_var <- 'CH4_logn1'
x_vars <- guild_vars$Guild

# Remove sample names
Guild_CH4_d0 <- Guild_CH4_d
row.names(Guild_CH4_d0) <- Guild_CH4_d0$Sample
Guild_CH4_d0 <- Guild_CH4_d0[,-1]

Guild_CH4_dS <- scale(Guild_CH4_d[,-1])              #  careful will scale y 
Guild_CH4_dS_df <- data.frame(Guild_CH4_dS)          #  make df
Guild_CH4_dS_df$CH4_logn1 <- Guild_CH4_d0$CH4_logn1  # fix CH4 scale to original
CH4_lass0 <- glmnet_lassoCV(y_var, x_vars, Guild_CH4_d0)
vars <- glmnet_coefs(CH4_lass0, output = 'vars')      # return only list of signif vars
vars
names(guild_colors)[1] <- "var"
CH4_lass0_cplot <- plot_lasso_coefs(CH4_lass0, guild_colors)
options(repr.plot.width=6, repr.plot.height=4)
CH4_lass0_cplot
# Out:
# [1] "best_lambda: 0.0239"
#      R2  RMSE
# 1 0.649 0.628
#  [1] "FeRB"    "FeOB"    "SRB"     "SOxB"    "Anamx"   "AOB"     "MOB_IIa"
#  [8] "MOB_II"  "MOB_I"   "CH4_ac"
# plot without title

# %%
coefs <- glmnet_coefs(CH4_lass0)              # Get significant effects

# %%
# merge w colors
coef_color <- data.frame(merge(coefs, guild_colors, all.x=T, by = 'var'))     # coef_color
colors2 <- as.character(coef_color$color)                               # only levels of var used  
colors2[is.na(colors2)] <- '#708090'                                    # replace NA color 
coef_color$color <- as.factor(colors2)                                  # replace colors (levels)

# %%
# reorder data / factors by coef
coef_color <- coef_color[order(coef_color$coef),]                       # sort by coef
coef_color$var <- reorder(coef_color$var, coef_color$coef)              # reorder var by coef
coef_color$color <- reorder(coef_color$color, coef_color$coef)          # reorder color by coef

# %%
coef_color
# Out:
#    var     coef       Index color
# 10 SRB     -0.3143048  3    #8B008B
# 6  MOB_I   -0.2700045 13    #63B8FF
# 8  MOB_IIa -0.2186047 11    #36648B
# 2  AOB     -0.1457117  8    #00CD00
# 5  FeRB    -0.1452769  1    #8B4513
# 1  Anamx    0.1100175  6    #00FF7F
# 7  MOB_II   0.1576897 12    #4F94CD
# 9  SOxB     0.2361266  5    #CD69C9
# 3  CH4_ac   0.3345343 14    #8B3626
# 4  FeOB     0.4042208  2    #CD6600

# %%
Guild_cols$Guild %in% coef_color$var
# Out:
#  [1]  TRUE  TRUE  TRUE FALSE  TRUE  TRUE FALSE  TRUE FALSE FALSE  TRUE  TRUE
# [13]  TRUE  TRUE FALSE FALSE FALSE

# %%
Guild_cols$Guild
# Out:
#  [1] "FeRB"    "FeOB"    "SRB"     "SRB_syn" "SOxB"    "Anamx"   "NOB"
#  [8] "AOB"     "AOA"     "MeOB"    "MOB_IIa" "MOB_II"  "MOB_I"   "CH4_ac"
# [15] "CH4_H2"  "CH4_me"  "CH4_mix"

# %%
# Add non-sig guilds (n = 7)
coef_color <- coef_color %>%
  add_row(var = "SRB_syn", coef = 0, Index = 4, color = "white") %>%
  add_row(var = "NOB", coef = 0, Index = 7, color = "white") %>%
  add_row(var = "AOA", coef = 0, Index = 9, color = "white") %>%
  add_row(var = "CH4_H2", coef = 0, Index = 15, color = "white") %>%
  add_row(var = "CH4_me", coef = 0, Index = 16, color = "white") %>%
  add_row(var = "CH4_mix", coef = 0, Index = 17, color = "white")

# %%
# reorder data / factors by coef
coef_color <- coef_color[order(coef_color$coef, decreasing = TRUE),]                       # sort by coef
coef_color$var <- reorder(coef_color$var, -coef_color$coef)              # reorder var by coef
coef_color$color <- reorder(coef_color$color, -coef_color$coef)          # reorder color by coef

# %%
# Make ggplot
options(repr.plot.width = 4, repr.plot.height = 6)
plot_colors <- c(paste(coef_color$color))
figS10a <- ggplot(data = coef_color, aes(x = var, y = coef, fill = var)) +
    geom_bar(stat = "identity") + 
    scale_fill_manual(values = plot_colors) + 
    coord_flip() + 
    labs(y = "Scaled LASSO\nCoefficient",
         x = "Guild") +
    theme_bw() +
    theme(legend.position = "none",
          panel.grid.major = element_blank(),
          panel.grid.minor = element_blank())
figS10a
# Out:
# plot without title

# %% [markdown]
# ## Figure 10b

# %%
Guild_CH4_d <- read.table("~/Documents/GitHub/SF_microbe_methane/data/SEM_data/SEM_base_log2_10_delta_guild_soil_data.txt")
dim(Guild_CH4_d)
# Out:
# [1] 65 51

# %%
# Now genera. Made table in other R Script (UpdatedCorrelationTables.R). Read in and merge by Sample ID
gen_tab <- read.table("~/Documents/GitHub/SF_microbe_methane/data/SEM_data/SEM_base_log2_10_delta_genera_soil_data.txt")
Guild_CH4_d <- Guild_CH4_d %>%
    left_join(., gen_tab, by = "Sample")

# %%
dim(Guild_CH4_d)
# Out:
# [1] 65 71

# %%
gen_guild <- read.table("~/Documents/GitHub/SF_microbe_methane/guild_analysis/Top20_SigGuild_Genera.txt", sep = "\t")
gen_guild
# Out:
#    Genus                    Guild
# 1  Crenothrix               MOB_I
# 2  Desulfatiglans           SRB
# 3  Desulfobacca             SRB
# 4  DesulfocapsaceaeFA       SRB
# 5  Desulfomonile            SRB
# 6  DesulfosarcinaceaeFA     SRB
# 7  DesulfuromonadaceaeFA    SRB
# 8  Ellin6067                AOB
# 9  GeobacteraceaeFA         FeRB
# 10 GOUTA6                   AOB
# 11 Leptolinea               FeOB
# 12 Methyloceanibacter       MOB_II
# 13 Methylocystis            MOB_IIa
# 14 MethyloligellaceaeFA     MOB_II
# 15 Methylotenera            MOB_I
# 16 MND1                     AOB
# 17 Rhodomicrobium           SOxB
# 18 Sva1033FA                SRB
# 19 ThermodesulfovibrioniaCL SRB
# 20 Thiobacillus             SOxB

# %%
guild_colors <- guild_colors %>%
    left_join(., gen_guild, by = c("var" = "Guild"))

# %%
names(guild_colors) <- c("Guild", "Index", "color", "var")

# %%
# Updated define_new_sem_table function
suppressWarnings(source('lasSEM_R_modules/lasSEM_3_SEM_basics_MI_COV_v1.12.R'))
# Out:
# [1] "ran SEM to create models: sem.ch4_mod0, sem.ch4_mod0a.1"
# [1] "ran SEM to create models: sem.ch4_mod0, sem.ch4_mod0a.1"
# Plot with title “”

# %%
source('lasSEM_R_modules/lasSEM_4_SEM_basics_example_v1.12.R')

# %%
names(Guild_CH4_d0)
# Out:
#  [1] "CH4_ug_m2_h" "CH4_logn1"   "CO2_mg_m2_h" "CH4_CO2"     "Bulk_dens"
#  [6] "H2O_FPS"     "pH"          "C"           "N"           "P"
# [11] "CN"          "NP"          "NO3_N"       "NH4_N"       "Olsen_P"
# [16] "NP_ext"      "Salinity.x"  "Cl"          "SO4"         "SO4_pw"
# [21] "Fe"          "Fe_pw"       "DOC_mg_L"    "CH4_mix"     "CH4_H2"
# [26] "CH4_ac"      "CH4_me"      "MOB_I"       "MOB_II"      "MOB_IIa"
# [31] "ANME"        "AOA"         "AOB"         "NOB"         "Anamx"
# [36] "SOxB"        "SRB_syn"     "SRB"         "FeOB"        "FeRB"
# [41] "Actino"      "Chlorf"      "Firmic"      "AO_NOB"      "NOB_AO"
# [46] "mcr_pmo"     "pmo_mcr"     "CH4_all"     "CH4_ac_mix"  "MOB_all"

# %%
# Need to get this plot for top 20 genera in significant guilds
y_var <- 'CH4_logn1'
x_vars <- gen_guild$Genus

# Remove sample names
Guild_CH4_d0 <- Guild_CH4_d
row.names(Guild_CH4_d0) <- Guild_CH4_d0$Sample
Guild_CH4_d0 <- Guild_CH4_d0[,-1]

Guild_CH4_dS <- scale(Guild_CH4_d[,-1])              #  careful will scale y 
Guild_CH4_dS_df <- data.frame(Guild_CH4_dS)          #  make df
Guild_CH4_dS_df$CH4_logn1 <- Guild_CH4_d0$CH4_logn1  # fix CH4 scale to original
CH4_lass0 <- glmnet_lassoCV(y_var, x_vars, Guild_CH4_d0)
vars <- glmnet_coefs(CH4_lass0, output = 'vars')      # return only list of signif vars
vars
#names(guild_colors)[1] <- "var"
CH4_lass0_cplot <- plot_lasso_coefs(CH4_lass0, guild_colors)
options(repr.plot.width=6, repr.plot.height=4)
CH4_lass0_cplot
# Out:
# [1] "best_lambda: 0.0339"
#      R2  RMSE
# 1 0.805 0.472
#  [1] "Desulfatiglans"     "Desulfobacca"       "Desulfomonile"
#  [4] "GeobacteraceaeFA"   "Leptolinea"         "Methyloceanibacter"
#  [7] "Methylocystis"      "Methylotenera"      "Sva1033FA"
# [10] "Thiobacillus"
# plot without title

# %%
coefs <- glmnet_coefs(CH4_lass0)              # Get significant effects

# %%
coefs
# Out:
#                    coef        var
# Desulfatiglans     -0.06955841 Desulfatiglans
# Desulfobacca       -0.36716834 Desulfobacca
# Desulfomonile      -0.07358556 Desulfomonile
# GeobacteraceaeFA   -0.12188126 GeobacteraceaeFA
# Leptolinea          0.58619263 Leptolinea
# Methyloceanibacter  0.16965120 Methyloceanibacter
# Methylocystis      -0.04327680 Methylocystis
# Methylotenera      -0.05301912 Methylotenera
# Sva1033FA          -0.34716116 Sva1033FA
# Thiobacillus        0.11621265 Thiobacillus

# %%
# merge w colors
coef_color <- data.frame(merge(coefs, guild_colors, all.x=T, by = 'var'))     # coef_color
colors2 <- as.character(coef_color$color)                               # only levels of var used  
colors2[is.na(colors2)] <- '#708090'                                    # replace NA color 
coef_color$color <- as.factor(colors2)                                  # replace colors (levels)

# %%
# reorder data / factors by coef
coef_color <- coef_color[order(coef_color$coef),]                       # sort by coef
coef_color$var <- reorder(coef_color$var, coef_color$coef)              # reorder var by coef
coef_color$color <- reorder(coef_color$color, coef_color$coef)          # reorder color by coef

# %%
coef_color
# Out:
#    var                coef        Guild   Index color
# 2  Desulfobacca       -0.36716834 SRB      3    #8B008B
# 9  Sva1033FA          -0.34716116 SRB      3    #8B008B
# 4  GeobacteraceaeFA   -0.12188126 FeRB     1    #8B4513
# 3  Desulfomonile      -0.07358556 SRB      3    #8B008B
# 1  Desulfatiglans     -0.06955841 SRB      3    #8B008B
# 8  Methylotenera      -0.05301912 MOB_I   13    #63B8FF
# 7  Methylocystis      -0.04327680 MOB_IIa 11    #36648B
# 10 Thiobacillus        0.11621265 SOxB     5    #CD69C9
# 6  Methyloceanibacter  0.16965120 MOB_II  12    #4F94CD
# 5  Leptolinea          0.58619263 FeOB     2    #CD6600

# %%
guild_colors$var %in% coef_color$var
# Out:
#  [1]  TRUE  TRUE  TRUE  TRUE FALSE  TRUE FALSE FALSE  TRUE FALSE FALSE FALSE
# [13]  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE FALSE FALSE
# [25]  TRUE FALSE FALSE FALSE FALSE

# %%
guild_colors$var
# Out:
#  [1] "GeobacteraceaeFA"         "Leptolinea"
#  [3] "Desulfatiglans"           "Desulfobacca"
#  [5] "DesulfocapsaceaeFA"       "Desulfomonile"
#  [7] "DesulfosarcinaceaeFA"     "DesulfuromonadaceaeFA"
#  [9] "Sva1033FA"                "ThermodesulfovibrioniaCL"
# [11] NA                         "Rhodomicrobium"
# [13] "Thiobacillus"             NA
# [15] NA                         "Ellin6067"
# [17] "GOUTA6"                   "MND1"
# [19] NA                         NA
# [21] "Methylocystis"            "Methyloceanibacter"
# [23] "MethyloligellaceaeFA"     "Crenothrix"
# [25] "Methylotenera"            NA
# [27] NA                         NA
# [29] NA

# %%
to_add <- as.data.frame(guild_colors$var) %>%
    set_names(c("var")) %>%
    filter(var %notin% coef_color$var) %>%
    filter(var != "NA")
to_add
# Out:
#    var
# 1  DesulfocapsaceaeFA
# 2  DesulfosarcinaceaeFA
# 3  DesulfuromonadaceaeFA
# 4  ThermodesulfovibrioniaCL
# 5  Rhodomicrobium
# 6  Ellin6067
# 7  GOUTA6
# 8  MND1
# 9  MethyloligellaceaeFA
# 10 Crenothrix

# %%
# Add non-sig guilds (n = 10)
coef_color <- coef_color %>%
  add_row(var = to_add$var[1], coef = 0, Index = 1, color = "white") %>%
  add_row(var = to_add$var[2], coef = 0, Index = 1, color = "white") %>%
  add_row(var = to_add$var[3], coef = 0, Index = 1, color = "white") %>%
  add_row(var = to_add$var[4], coef = 0, Index = 1, color = "white") %>%
  add_row(var = to_add$var[5], coef = 0, Index = 1, color = "white") %>%
  add_row(var = to_add$var[6], coef = 0, Index = 1, color = "white") %>%
  add_row(var = to_add$var[7], coef = 0, Index = 1, color = "white") %>%
  add_row(var = to_add$var[8], coef = 0, Index = 1, color = "white") %>%
  add_row(var = to_add$var[9], coef = 0, Index = 1, color = "white") %>%
  add_row(var = to_add$var[10], coef = 0, Index = 1, color = "white")

# %%
# reorder data / factors by coef
coef_color <- coef_color[order(coef_color$coef, decreasing = TRUE),]                       # sort by coef
coef_color$var <- reorder(coef_color$var, -coef_color$coef)              # reorder var by coef
coef_color$color <- reorder(coef_color$color, -coef_color$coef)          # reorder color by coef

# %%
# Make ggplot
options(repr.plot.width = 4, repr.plot.height = 6)
plot_colors <- c(paste(coef_color$color))
figS10b <- ggplot(data = coef_color, aes(x = var, y = coef, fill = var)) +
    geom_bar(stat = "identity") + 
    scale_fill_manual(values = plot_colors) + 
    coord_flip() + 
    labs(y = "Scaled LASSO\nCoefficient",
         x = "Genus") +
    theme_bw() +
    theme(legend.position = "none",
          panel.grid.major = element_blank(),
          panel.grid.minor = element_blank())
figS10b
# Out:
# plot without title

# %%
# Make multipanel plot S10
options(repr.plot.width = 8, repr.plot.height = 6)
figs10 <- plot_grid(figS10a, figS10b, rel_widths = c(0.45, 0.55), labels = "auto")
figs10
pdf("~/Documents/GitHub/SF_microbe_methane/figs/FigureS10.pdf", width = 8, height = 6)
figs10
dev.off()
# Out:
# pdf
#   2
# plot without title

# %% [markdown]
# # Continue Wyatt Script

# %%
# Filter step troubleshoot
# semF <-sem_filter(subs, data = Guild_CH4_dS_df, top_n_models = 140, sort_by = 'aic', n_mod_ret = 140)
# semF <-sem_filterP(subs, data = Guild_CH4_dS_df, top_n_models = 140, sort_by = 'aic', ncores = 20) # depricate , n_mod_ret = 140,  
#filt_models <- filter_byLM_resid(semF, n_keep_split = 3, R2_filter = 0.5, resid_0filter = TRUE)
# reduce candidate models by top n (subtests)
mod_cands <- subs[1:140,]                              # subset
mods <- mod_cands$model                                            # get models

# %%
# orig feats to keep 
keep_orig <- c("n_pred", "AIC", "BIC", "AICc")
orig_feats <- mod_cands[keep_orig]
names(orig_feats) <- c("n_pred","aic_glm","bic_glm","aicc_glm")
orig_feats$n_pred <- orig_feats$n_pred - 1                         # note init n_pred incl. y

# %%
# Get performance metrics for each
mod_outs = {}

# %%
length(mods)
# Out:
# [1] 140

# %%
mods
# Out:
#   [1] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + MOB_IIa + ANME + CH4_ac_mix"
#   [2] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME + AOB"
#   [3] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + MOB_IIa + ANME + CH4_ac_mix"
#   [4] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME"
#   [5] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + pH + ANME + CH4_ac_mix"
#   [6] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + ANME + AOB"
#   [7] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_me + MOB_IIa + ANME"
#   [8] "CH4_logn1  ~  CO2_mg_m2_h + MOB_IIa + ANME + CH4_ac_mix"
#   [9] "CH4_logn1  ~  CO2_mg_m2_h + CH4_ac + MOB_IIa + ANME"
#  [10] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + pH + MOB_IIa + CH4_ac_mix"
#  [11] "CH4_logn1  ~  CO2_mg_m2_h + ANME + AOB"
#  [12] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + MOB_IIa + CH4_ac_mix"
#  [13] "CH4_logn1  ~  CO2_mg_m2_h + CH4_me + MOB_IIa + ANME"
#  [14] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + pH + CH4_me + ANME"
#  [15] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + CH4_me + MOB_IIa"
#  [16] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + ANME + CH4_ac_mix"
#  [17] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + MOB_IIa + CH4_ac_mix"
#  [18] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_me + MOB_IIa + AOB"
#  [19] "CH4_logn1  ~  CO2_mg_m2_h + CH4_ac + ANME"
#  [20] "CH4_logn1  ~  CO2_mg_m2_h + pH + ANME + CH4_ac_mix"
#  [21] "CH4_logn1  ~  CO2_mg_m2_h + H2O_FPS + ANME + CH4_ac_mix"
#  [22] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_me + ANME"
#  [23] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + MOB_IIa + AOB"
#  [24] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_me + MOB_IIa"
#  [25] "CH4_logn1  ~  CO2_mg_m2_h + pH + CH4_me + ANME"
#  [26] "CH4_logn1  ~  CO2_mg_m2_h + ANME + CH4_ac_mix"
#  [27] "CH4_logn1  ~  CO2_mg_m2_h + CH4_me + ANME"
#  [28] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + MOB_IIa"
#  [29] "CH4_logn1  ~  CO2_mg_m2_h + H2O_FPS + MOB_IIa + CH4_ac_mix"
#  [30] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + pH + AOB + CH4_ac_mix"
#  [31] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + MOB_IIa + AOB"
#  [32] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + pH + CH4_me + AOB"
#  [33] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + pH + CH4_ac + CH4_ac_mix"
#  [34] "CH4_logn1  ~  CO2_mg_m2_h + H2O_FPS + CH4_me + MOB_IIa"
#  [35] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + AOB"
#  [36] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + pH + CH4_ac + CH4_me"
#  [37] "CH4_logn1  ~  CO2_mg_m2_h + ANME"
#  [38] "CH4_logn1  ~  CO2_mg_m2_h + MOB_IIa + CH4_ac_mix"
#  [39] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_me + AOB"
#  [40] "CH4_logn1  ~  CO2_mg_m2_h + CH4_me + MOB_IIa"
#  [41] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + pH + CH4_ac_mix"
#  [42] "CH4_logn1  ~  CO2_mg_m2_h + H2O_FPS + CH4_ac + MOB_IIa"
#  [43] "CH4_logn1  ~  CO2_mg_m2_h + MOB_IIa + AOB"
#  [44] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + pH + CH4_ac"
#  [45] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + H2O_FPS + CH4_ac + CH4_ac_mix"
#  [46] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + AOB"
#  [47] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + H2O_FPS + CH4_ac + CH4_me"
#  [48] "CH4_logn1  ~  CO2_mg_m2_h + CH4_ac + MOB_IIa"
#  [49] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + pH + CH4_me"
#  [50] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + CH4_me"
#  [51] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac"
#  [52] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + H2O_FPS + CH4_ac_mix"
#  [53] "CH4_logn1  ~  CO2_mg_m2_h + H2O_FPS + pH + CH4_ac_mix"
#  [54] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + H2O_FPS + CH4_me"
#  [55] "CH4_logn1  ~  CO2_mg_m2_h + H2O_FPS + pH + AOB"
#  [56] "CH4_logn1  ~  CO2_mg_m2_h + MOB_IIa"
#  [57] "CH4_logn1  ~  CO2_mg_m2_h + H2O_FPS + pH + CH4_me"
#  [58] "CH4_logn1  ~  CO2_mg_m2_h + H2O_FPS + AOB"
#  [59] "CH4_logn1  ~  CO2_mg_m2_h + H2O_FPS + pH + CH4_ac"
#  [60] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_me"
#  [61] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac_mix"
#  [62] "CH4_logn1  ~  CO2_mg_m2_h + H2O_FPS + CH4_ac"
#  [63] "CH4_logn1  ~  CO2_mg_m2_h + pH + AOB"
#  [64] "CH4_logn1  ~  CO2_mg_m2_h + H2O_FPS + CH4_ac_mix"
#  [65] "CH4_logn1  ~  CO2_mg_m2_h + H2O_FPS + CH4_me"
#  [66] "CH4_logn1  ~  CO2_mg_m2_h + H2O_FPS + pH"
#  [67] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + pH"
#  [68] "CH4_logn1  ~  CO2_mg_m2_h + pH + CH4_ac_mix"
#  [69] "CH4_logn1  ~  CO2_mg_m2_h + pH + CH4_ac"
#  [70] "CH4_logn1  ~  CO2_mg_m2_h + pH + CH4_me"
#  [71] "CH4_logn1  ~  H2O_FPS + ANME + CH4_ac_mix"
#  [72] "CH4_logn1  ~  CO2_mg_m2_h + AOB"
#  [73] "CH4_logn1  ~  H2O_FPS + CH4_me + ANME"
#  [74] "CH4_logn1  ~  H2O_FPS + CH4_ac + ANME"
#  [75] "CH4_logn1  ~  CO2_mg_m2_h + pH"
#  [76] "CH4_logn1  ~  H2O_FPS + MOB_IIa + CH4_ac_mix"
#  [77] "CH4_logn1  ~  H2O_FPS + CH4_me + MOB_IIa"
#  [78] "CH4_logn1  ~  H2O_FPS + CH4_ac + CH4_me"
#  [79] "CH4_logn1  ~  H2O_FPS + CH4_ac_mix"
#  [80] "CH4_logn1  ~  CO2_mg_m2_h + H2O_FPS"
#  [81] "CH4_logn1  ~  H2O_FPS + CH4_me"
#  [82] "CH4_logn1  ~  H2O_FPS + CH4_ac"
#  [83] "CH4_logn1  ~  H2O_FPS + pH + ANME + AOB"
#  [84] "CH4_logn1  ~  CH4_ac + ANME"
#  [85] "CH4_logn1  ~  H2O_FPS + ANME + AOB"
#  [86] "CH4_logn1  ~  CH4_me + ANME"
#  [87] "CH4_logn1  ~  ANME + CH4_ac_mix"
#  [88] "CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens"
#  [89] "CH4_logn1  ~  Bulk_dens + H2O_FPS + ANME"
#  [90] "CH4_logn1  ~  H2O_FPS + AOB"
#  [91] "CH4_logn1  ~  ANME + AOB"
#  [92] "CH4_logn1  ~  Bulk_dens + CH4_ac + CH4_me + MOB_IIa"
#  [93] "CH4_logn1  ~  CO2_mg_m2_h + CH4_ac"
#  [94] "CH4_logn1  ~  Bulk_dens + CH4_ac + MOB_IIa + CH4_ac_mix"
#  [95] "CH4_logn1  ~  Bulk_dens + CH4_ac + CH4_me"
#  [96] "CH4_logn1  ~  Bulk_dens + CH4_ac + AOB"
#  [97] "CH4_logn1  ~  Bulk_dens + CH4_me + AOB"
#  [98] "CH4_logn1  ~  CH4_me + MOB_IIa"
#  [99] "CH4_logn1  ~  CO2_mg_m2_h + CH4_me"
# [100] "CH4_logn1  ~  Bulk_dens + CH4_ac"
# [101] "CH4_logn1  ~  MOB_IIa + CH4_ac_mix"
# [102] "CH4_logn1  ~  Bulk_dens + AOB + CH4_ac_mix"
# [103] "CH4_logn1  ~  Bulk_dens + ANME"
# [104] "CH4_logn1  ~  CH4_ac + MOB_IIa"
# [105] "CH4_logn1  ~  CO2_mg_m2_h"
# [106] "CH4_logn1  ~  H2O_FPS + ANME"
# [107] "CH4_logn1  ~  Bulk_dens + AOB"
# [108] "CH4_logn1  ~  MOB_IIa + AOB"
# [109] "CH4_logn1  ~  ANME"
# [110] "CH4_logn1  ~  Bulk_dens + CH4_me"
# [111] "CH4_logn1  ~  Bulk_dens + H2O_FPS + MOB_IIa"
# [112] "CH4_logn1  ~  AOB"
# [113] "CH4_logn1  ~  Bulk_dens + CH4_ac_mix"
# [114] "CH4_logn1  ~  Bulk_dens + H2O_FPS"
# [115] "CH4_logn1  ~  H2O_FPS"
# [116] "CH4_logn1  ~  pH + CH4_ac"
# [117] "CH4_logn1  ~  pH + CH4_me"
# [118] "CH4_logn1  ~  CH4_ac"
# [119] "CH4_logn1  ~  pH + CH4_ac_mix"
# [120] "CH4_logn1  ~  MOB_IIa"
# [121] "CH4_logn1  ~  CH4_me"
# [122] "CH4_logn1  ~  CH4_ac_mix"
# [123] "CH4_logn1  ~  pH"
# [124] NA
# [125] NA
# [126] NA
# [127] NA
# [128] NA
# [129] NA
# [130] NA
# [131] NA
# [132] NA
# [133] NA
# [134] NA
# [135] NA
# [136] NA
# [137] NA
# [138] NA
# [139] NA
# [140] NA

# %%
# Looks like mod 140 with NA was causing errors. run 1:139
for (i in seq(1:139)){

    # Get SEM model
    form <- paste(mods[4])
    SEM_mod <- sem(form, data = data, fixed.x=FALSE, estimator = 'mlm', orthogonal = TRUE)
    
    # Get R2 data
    r2 <- get_SEM_R2s(SEM_mod)
    R2 <-r2[,1]
    
    # Get aic, bic data
    keep <- c('aic','bic','npar')
    fits <- sem_fit_sum(SEM_mod, sem_fit_params)
    fits <- fits[keep]
      
    # all feats significant?
    sig_test <- get_SEM_nonsig_vars(SEM_mod, p_cut =0.05)
    if (dim(sig_test)[1] == 0){
        all_sig <- 'yes'
        } else {
        all_sig <- 'no'
        }
        
    # get feats from original data
    keep_orig <- orig_feats[4,]        
                            
    # combine feats & assign to list
    out <- data.frame(fits, R2, form, all_sig, keep_orig)
    mod_outs[[4]] <- out #paste(mods[i])
    
    }

# %%
# Assemble and sort list
output <- data.frame(do.call(rbind, mod_outs))
output <- output[order(output['aic']),]
    
# clean and return output
model <- seq(1:(length(mods)))
output <- data.frame(model, output)
    
    
output <- output[output$all_sig == 'yes',]
output <- output[1:(139),]
output <- output[complete.cases(output),]
row.names(output) <- output$model
return(output)
# Out:
#     model aic    bic     npar R2
# 1    1    835.94 868.555 15   SEM_mod
# 2    2    835.94 868.555 15   SEM_mod
# 3    3    835.94 868.555 15   SEM_mod
# 4    4    835.94 868.555 15   SEM_mod
# 5    5    835.94 868.555 15   SEM_mod
# 6    6    835.94 868.555 15   SEM_mod
# 7    7    835.94 868.555 15   SEM_mod
# 8    8    835.94 868.555 15   SEM_mod
# 9    9    835.94 868.555 15   SEM_mod
# 10  10    835.94 868.555 15   SEM_mod
# 11  11    835.94 868.555 15   SEM_mod
# 12  12    835.94 868.555 15   SEM_mod
# 13  13    835.94 868.555 15   SEM_mod
# 14  14    835.94 868.555 15   SEM_mod
# 15  15    835.94 868.555 15   SEM_mod
# 16  16    835.94 868.555 15   SEM_mod
# 17  17    835.94 868.555 15   SEM_mod
# 18  18    835.94 868.555 15   SEM_mod
# 19  19    835.94 868.555 15   SEM_mod
# 20  20    835.94 868.555 15   SEM_mod
# 21  21    835.94 868.555 15   SEM_mod
# 22  22    835.94 868.555 15   SEM_mod
# 23  23    835.94 868.555 15   SEM_mod
# 24  24    835.94 868.555 15   SEM_mod
# 25  25    835.94 868.555 15   SEM_mod
# 26  26    835.94 868.555 15   SEM_mod
# 27  27    835.94 868.555 15   SEM_mod
# 28  28    835.94 868.555 15   SEM_mod
# 29  29    835.94 868.555 15   SEM_mod
# 30  30    835.94 868.555 15   SEM_mod
# ⋮   ⋮     ⋮      ⋮       ⋮    ⋮
# 110 110   835.94 868.555 15   SEM_mod
# 111 111   835.94 868.555 15   SEM_mod
# 112 112   835.94 868.555 15   SEM_mod
# 113 113   835.94 868.555 15   SEM_mod
# 114 114   835.94 868.555 15   SEM_mod
# 115 115   835.94 868.555 15   SEM_mod
# 116 116   835.94 868.555 15   SEM_mod
# 117 117   835.94 868.555 15   SEM_mod
# 118 118   835.94 868.555 15   SEM_mod
# 119 119   835.94 868.555 15   SEM_mod
# 120 120   835.94 868.555 15   SEM_mod
# 121 121   835.94 868.555 15   SEM_mod
# 122 122   835.94 868.555 15   SEM_mod
# 123 123   835.94 868.555 15   SEM_mod
# 124 124   835.94 868.555 15   SEM_mod
# 125 125   835.94 868.555 15   SEM_mod
# 126 126   835.94 868.555 15   SEM_mod
# 127 127   835.94 868.555 15   SEM_mod
# 128 128   835.94 868.555 15   SEM_mod
# 129 129   835.94 868.555 15   SEM_mod
# 130 130   835.94 868.555 15   SEM_mod
# 131 131   835.94 868.555 15   SEM_mod
# 132 132   835.94 868.555 15   SEM_mod
# 133 133   835.94 868.555 15   SEM_mod
# 134 134   835.94 868.555 15   SEM_mod
# 135 135   835.94 868.555 15   SEM_mod
# 136 136   835.94 868.555 15   SEM_mod
# 137 137   835.94 868.555 15   SEM_mod
# 138 138   835.94 868.555 15   SEM_mod
# 139 139   835.94 868.555 15   SEM_mod
#     form                                                  all_sig n_pred
# 1   CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 2   CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 3   CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 4   CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 5   CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 6   CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 7   CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 8   CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 9   CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 10  CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 11  CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 12  CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 13  CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 14  CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 15  CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 16  CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 17  CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 18  CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 19  CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 20  CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 21  CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 22  CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 23  CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 24  CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 25  CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 26  CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 27  CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 28  CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 29  CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 30  CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# ⋮   ⋮                                                     ⋮       ⋮
# 110 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 111 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 112 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 113 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 114 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 115 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 116 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 117 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 118 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 119 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 120 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 121 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 122 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 123 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 124 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 125 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 126 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 127 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 128 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 129 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 130 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 131 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 132 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 133 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 134 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 135 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 136 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 137 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 138 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
# 139 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4
#     aic_glm  bic_glm  aicc_glm
# 1   80.86829 93.91461 82.31656
# 2   80.86829 93.91461 82.31656
# 3   80.86829 93.91461 82.31656
# 4   80.86829 93.91461 82.31656
# 5   80.86829 93.91461 82.31656
# 6   80.86829 93.91461 82.31656
# 7   80.86829 93.91461 82.31656
# 8   80.86829 93.91461 82.31656
# 9   80.86829 93.91461 82.31656
# 10  80.86829 93.91461 82.31656
# 11  80.86829 93.91461 82.31656
# 12  80.86829 93.91461 82.31656
# 13  80.86829 93.91461 82.31656
# 14  80.86829 93.91461 82.31656
# 15  80.86829 93.91461 82.31656
# 16  80.86829 93.91461 82.31656
# 17  80.86829 93.91461 82.31656
# 18  80.86829 93.91461 82.31656
# 19  80.86829 93.91461 82.31656
# 20  80.86829 93.91461 82.31656
# 21  80.86829 93.91461 82.31656
# 22  80.86829 93.91461 82.31656
# 23  80.86829 93.91461 82.31656
# 24  80.86829 93.91461 82.31656
# 25  80.86829 93.91461 82.31656
# 26  80.86829 93.91461 82.31656
# 27  80.86829 93.91461 82.31656
# 28  80.86829 93.91461 82.31656
# 29  80.86829 93.91461 82.31656
# 30  80.86829 93.91461 82.31656
# ⋮   ⋮        ⋮        ⋮
# 110 80.86829 93.91461 82.31656
# 111 80.86829 93.91461 82.31656
# 112 80.86829 93.91461 82.31656
# 113 80.86829 93.91461 82.31656
# 114 80.86829 93.91461 82.31656
# 115 80.86829 93.91461 82.31656
# 116 80.86829 93.91461 82.31656
# 117 80.86829 93.91461 82.31656
# 118 80.86829 93.91461 82.31656
# 119 80.86829 93.91461 82.31656
# 120 80.86829 93.91461 82.31656
# 121 80.86829 93.91461 82.31656
# 122 80.86829 93.91461 82.31656
# 123 80.86829 93.91461 82.31656
# 124 80.86829 93.91461 82.31656
# 125 80.86829 93.91461 82.31656
# 126 80.86829 93.91461 82.31656
# 127 80.86829 93.91461 82.31656
# 128 80.86829 93.91461 82.31656
# 129 80.86829 93.91461 82.31656
# 130 80.86829 93.91461 82.31656
# 131 80.86829 93.91461 82.31656
# 132 80.86829 93.91461 82.31656
# 133 80.86829 93.91461 82.31656
# 134 80.86829 93.91461 82.31656
# 135 80.86829 93.91461 82.31656
# 136 80.86829 93.91461 82.31656
# 137 80.86829 93.91461 82.31656
# 138 80.86829 93.91461 82.31656
# 139 80.86829 93.91461 82.31656

# %%
semF <- output

# %%
# source('lasSEM_R_modules/lasSEM_5_ML_feat_sel_LAS_GLM_SEM_v1.12.R')   # slow examples

# %%
# HELPER fxn -- get ggplot color wheel hue function -- Maybe use later?
gg_color_hue <- function(n) {
  hues = seq(15, 375, length = (n + 1))
  hcl(h = hues, l = 65, c = 100)[1:n]
}

########################################################################################
### a) plot SEM LASSO models
plot_SEM_lasso_mods = function(sem_tab, label = 'FALSE', colors = ''){
    
    
    # Get color palette, default or custom
    options(warn=-1)                                            # need to supress warning in this function
    if (colors == ''){                                          # if (colors warns for vector, not needed
          cols <- gg_color_hue(max(sem_tab$n_pred))} else {     # default ggplot colors  OR
          cols <- colors}                                       # custom color input     generated in combined plots  
    
    # Get n_pred as factor 
    sem_tab$n_pred <- factor(sem_tab$n_pred)
      
    # plot w/o labels
    no_lab <- ggplot(sem_tab, aes(x=aic, y=R2, color = n_pred)) + geom_point() +
                    theme_minimal() + scale_color_manual(values = cols) #+ 
                    #geom_smooth(method=lm, aes(fill = n_pred))
    
    # plot w labels
    label_plot <- ggplot(sem_tab, aes(x=aic, y=R2, color = n_pred, label = model)) + geom_point() +
                     geom_text_repel() + theme_minimal() + scale_color_manual(values = cols)
    
    # is plot labeled?
    if (label == 'FALSE'){
          out_plot <- no_lab} else {
          out_plot <- label_plot}
    
    return(out_plot)    
}

#head(asemF)

# Demonstrate function
all_models <- plot_SEM_lasso_mods(semF)
#all_models <- plot_SEM_lasso_mods(asemF)

options(repr.plot.width=4.5, repr.plot.height=4)
all_models

# With restricted input, labels  -- Incorporated into g) below
semF_top_n <- semF[order(semF$aic_glm),]
semF_top_n <- semF_top_n[1:25,]

# plot selected models
select_models <- plot_SEM_lasso_mods(semF_top_n, label = 'TRUE')
select_models
# Out:
# plot without title
# plot without title

# %%
head(semF)
# Out:
#   model aic    bic     npar R2
# 1 1     835.94 868.555 15   SEM_mod
# 2 2     835.94 868.555 15   SEM_mod
# 3 3     835.94 868.555 15   SEM_mod
# 4 4     835.94 868.555 15   SEM_mod
# 5 5     835.94 868.555 15   SEM_mod
# 6 6     835.94 868.555 15   SEM_mod
#   form                                                  all_sig n_pred aic_glm
# 1 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4      80.86829
# 2 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4      80.86829
# 3 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4      80.86829
# 4 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4      80.86829
# 5 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4      80.86829
# 6 CH4_logn1  ~  CO2_mg_m2_h + Bulk_dens + CH4_ac + ANME yes     4      80.86829
#   bic_glm  aicc_glm
# 1 93.91461 82.31656
# 2 93.91461 82.31656
# 3 93.91461 82.31656
# 4 93.91461 82.31656
# 5 93.91461 82.31656
# 6 93.91461 82.31656

# %%
# Troubleshoot - issue is sel_models R2 just says 'SEM_mod'
# Demonstrate function
get_models <- c(34, 35, 67, 69, 82, 107, 113, 116) 
sel_models <- semF[semF$model %in% get_models,]

# %%
sel_models$aic
# Out:
# [1] 835.94 835.94 835.94 835.94 835.94 835.94 835.94 835.94

# %%
sel_models$R2
# Out:
# [1] "SEM_mod" "SEM_mod" "SEM_mod" "SEM_mod" "SEM_mod" "SEM_mod" "SEM_mod"
# [8] "SEM_mod"

# %%
# params from selected
selected <- sel_models$model                                                                   # selected mods
x_min <- min(sel_models$aic)*0.9
y_min <- min(sel_models$R2)*0.9
# Out:
# Error in min(sel_models$R2) * 0.9: non-numeric argument to binary operator
# Traceback:

# %%
# suppressMessages(source('lasSEM_R_modules/lasSEM_6_Plot_LASSO_SEM_model_screening_v1.12.R'))

# %%
source('lasSEM_R_modules/lasSEM_7_SEM_model_VIP_sorting_v1.12.R')
#setwd('~/Desktop/Sal_SEM_models')
# Out:
# Error in coef_sort_sem_form_tab(lasso_model, sel_models, sep_table = "TRUE", : object 'filt_models' not found
# Traceback:
#
# 1. source("lasSEM_R_modules/lasSEM_7_SEM_model_VIP_sorting_v1.12.R")
# 2. withVisible(eval(ei, envir))
# 3. eval(ei, envir)
# 4. eval(ei, envir)
# 5. sort_sem_model_coef_mtx(CH4_lass0, filt_models)
# 6. coef_sort_sem_form_tab(lasso_model, sel_models, sep_table = "TRUE",
#  .     fxn_operator = "~ ")

# %%
source('lasSEM_R_modules/lasSEM_8_SEM_model_selection_plot_components_heat_clust_v1.12.R')
# Out:
# Error in as.matrix(x): object 'vip_matrix' not found
# Traceback:
#
# 1. source("lasSEM_R_modules/lasSEM_8_SEM_model_selection_plot_components_heat_clust_v1.12.R")
# 2. withVisible(eval(ei, envir))
# 3. eval(ei, envir)
# 4. eval(ei, envir)
# 5. model_cluster_dend(vip_matrix, k_clusts = 3)
# 6. dist(sem_mod_mtx, method = "euclidean")
# 7. as.matrix(x)

# %%
suppressMessages(source('lasSEM_R_modules/lasSEM_9_lasSEM_combined_model_selection_plots_v1.12.R'))
# Out:
# Error in eval(ei, envir): object 'semF' not found
# Traceback:
#
# 1. suppressMessages(source("lasSEM_R_modules/lasSEM_9_lasSEM_combined_model_selection_plots_v1.12.R"))
# 2. withCallingHandlers(expr, message = function(c) if (inherits(c,
#  .     classes)) tryInvokeRestart("muffleMessage"))
# 3. source("lasSEM_R_modules/lasSEM_9_lasSEM_combined_model_selection_plots_v1.12.R")
# 4. withVisible(eval(ei, envir))
# 5. eval(ei, envir)
# 6. eval(ei, envir)

# %%
suppressMessages(source('lasSEM_R_modules/lasSEM_10_lasSEM_combined_workflow_plot_wrappers_v1.12.R'))  # slow ex
# Out:
# [1] "best_lambda: 0.041"
#      R2  RMSE
# 1 0.862 0.398
# [1] "best_lambda: 0.0284"
#      R2  RMSE
# 1 0.866 0.389
# Error in sort_sem_model_coef_mtx(lasso_model, sem_models, color_var = "n_pred"): could not find function "sort_sem_model_coef_mtx"
# Traceback:
#
# 1. suppressMessages(source("lasSEM_R_modules/lasSEM_10_lasSEM_combined_workflow_plot_wrappers_v1.12.R"))
# 2. withCallingHandlers(expr, message = function(c) if (inherits(c,
#  .     classes)) tryInvokeRestart("muffleMessage"))
# 3. source("lasSEM_R_modules/lasSEM_10_lasSEM_combined_workflow_plot_wrappers_v1.12.R")
# 4. withVisible(eval(ei, envir))
# 5. eval(ei, envir)
# 6. eval(ei, envir)
# 7. keep_only_models(CH4_lass0, subs2, force_filt = c("SO4", "N"),
#  .     all_any = "any")

# %%
source('lasSEM_R_modules/lasSEM_11_SEM_autocompositing_v1.12.R')       # slow ex
# Out:
# Error in file(file, "rt"): cannot open the connection
# Traceback:
#
# 1. source("lasSEM_R_modules/lasSEM_11_SEM_autocompositing_v1.12.R")
# 2. withVisible(eval(ei, envir))
# 3. eval(ei, envir)
# 4. eval(ei, envir)
# 5. read.table("SEM_models/fxn_example_tables/SEM_Exper7_res_CH4_lasso.txt",
#  .     sep = "\t")
# 6. file(file, "rt")

# %%
source('lasSEM_R_modules/lasSEM_12_SEM_branching_workflow_wrappers_v1.12.R')

# %%
# source('lasSEM_R_modules/ ')

# %%
# source('lasSEM_R_modules/ ')

# %% [markdown]
# # 2) user definitions for model inputs

# %% [markdown]
# ### a) SEM model metrics to report

# %%
# need to verify that passing these variables is "open" where models run
# sem_fit_params <- c( "pvalue", "chisq", "df", "npar","aic", "bic", "gfi", "cfi", "rni", "rmsea", "srmr")

# %% [markdown]
# ### b) variable subsets for gas, soils, guilds

# %%
# rename col to var
# names(guild_colors)[1] <- "var"
# colors <- guild_colors

# %%
guild_colors
# Out:
#       var     Index color
# 15    FeRB     1    #8B4513
# 14    FeOB     2    #CD6600
# 13    SRB      3    #8B008B
# 12    SRB_syn  4    #CD2990
# 11    SOxB     5    #CD69C9
# 10    Anamx    6    #00FF7F
# 9     NOB      7    #008B00
# 8     AOB      8    #00CD00
# 7     AOA      9    #7CFC00
# 6     MeOB    10    #836FFF
# 5     MOB_IIa 11    #36648B
# 4     MOB_II  12    #4F94CD
# 3     MOB_I   13    #63B8FF
# 2     CH4_ac  14    #8B3626
# 1     CH4_H2  15    #CD4F39
# ...16 CH4_me  16    #FDC086
# ...17 CH4_mix 17    #FFFF99

# %% [raw]
# # get soil, guild var sets for models -- # verify
# xvars0 <-names(Guild_CH4_d0)
#
# # vars to exclude (maybe)
# drop_gas <- c('CH4_ug_m2_h', 'CH4_logn1','CH4_CO2', 'CO2_soilC_mg_g_d') # keep this: ,'CO2_mg_m2_h',
# drop_ratios <- c('CN','CP','NP','NP_ext')
# drop_pw <- c('SO4_pw', 'Fe_pw','Fe','DOC_mg_L')
# drop_guilds <- c('SOxB','MeOB','FeOB','AO_NOB','NOB_AO','mcr_pmo', 'pmo_mcr','Anamx')
# drop_taxa <- c('Actino','Chlorf','Firmic')
#
# # Get combined drop lists
# drop_vars1 <- c(drop_gas, drop_pw, drop_guilds, drop_taxa, drop_ratios)
#
# # Select guild & chem data:                # Remove drop vars from list
# xvars1 <- xvars0[!xvars0 %in% drop_vars1]

# %% [markdown]
# ### c) variable compositing rules

# %% [raw]
# ## 0) USER DEFINE variable assignments for composite functions -- MOVE TO EXAMPLES AT TOP, out to usr notebooks
#
# CH4_gen <- c("CH4_ac", "CH4_H2", "CO2_mg_m2_h", "Salinity.x", "SO4", "SRB", "FeRB", "NP")
#
# CH4_ox <- c("MOB_IIa", "MOB_I", "MOB_II", "Bulk_dens", "H2O_FPS",
#             "N", "AOB", "AOA", "NOB", "NO3_N", "NH4_N", "NO3_NH4")
#
# composite_sets <- c("CH4_gen", "CH4_ox")
# # Composite_base <- c('0 + CH4_gen + CH4_ox')

# %% [markdown]
# # 3) lasSEM model selection workflow for SEM branches/ leaves

# %% [markdown]
# ## 0) Data preparation: scaling & var subsets
#
# - Guild_CH4_dS  (delta, scaled)
# - drop_x sets for: gas, ratios, pw, guilds, taxa  (extraneous guilds, etc)
# - drop_vars1 = all drop_x's combined
# - x_vars drops these from all vars, is base set (though note missing ratios, porewater)
# - other x_var sets derived as needed

# %%
# Remove sample names
Guild_CH4_d0 <- Guild_CH4_d
row.names(Guild_CH4_d0) <- Guild_CH4_d0$Sample
Guild_CH4_d0 <- Guild_CH4_d0[,-1]

# %%
# SCALE ALL, needed for some functions (SEM screening)
Guild_CH4_dS <- scale(Guild_CH4_d0)              #  careful will scale y 
Guild_CH4_dS <- data.frame(Guild_CH4_dS)          #  make df
Guild_CH4_dS$CH4_logn1 <- Guild_CH4_d0$CH4_logn1  # fix CH4 scale to original

# %%
names(Guild_CH4_dS)
# Out:
#  [1] "CH4_ug_m2_h"      "CH4_logn1"        "CO2_mg_m2_h"      "CO2_soilC_mg_g_d"
#  [5] "CH4_CO2"          "Bulk_dens"        "H2O_FPS"          "pH"
#  [9] "C"                "N"                "P"                "CN"
# [13] "NP"               "NO3_N"            "NH4_N"            "Olsen_P"
# [17] "NO3_NH4"          "NP_ext"           "Salinity.x"       "Cl"
# [21] "SO4"              "SO4_pw"           "Fe"               "Fe_pw"
# [25] "DOC_mg_L"         "CH4_H2"           "CH4_ac"           "MOB_I"
# [29] "MOB_II"           "MOB_IIa"          "MeOB"             "AOA"
# [33] "AOB"              "NOB"              "Anamx"            "SOxB"
# [37] "SRB_syn"          "SRB"              "FeOB"             "FeRB"
# [41] "Actino"           "Chlorf"           "Firmic"           "AO_NOB"
# [45] "NOB_AO"           "mcr_pmo"          "pmo_mcr"

# %%
# prepare variable SUBSETS 

# get all vars
xvars0 <-names(Guild_CH4_dS)

# vars to exclude (maybe)
drop_gas <- c('CH4_ug_m2_h', 'CH4_logn1', 'CH4_CO2', 'CO2_soilC_mg_g_d') # keep this: ,'CO2_mg_m2_h',
drop_ratios <- c('CN','CP','NP','NO3_NH4','NP_ext')
drop_pw <- c('SO4_pw','Fe_pw','Fe','DOC_mg_L')
drop_guilds <- c('SOxB','MeOB','FeOB','AO_NOB','NOB_AO','mcr_pmo', 'pmo_mcr','Anamx')
drop_taxa <- c('Actino','Chlorf','Firmic')

# Get combined drop lists
drop_vars1 <- c(drop_gas, drop_pw, drop_guilds, drop_taxa, drop_ratios)

# %%
# Select guild & chem data:                # Remove drop vars from list
xvars1 <- xvars0[!xvars0 %in% drop_vars1]

# alternately, may want only guild or chem data lists, including ALL

# %% [markdown]
# ## a) CH4 model:  Base LASSO feature selection
#
# - compare all vars, limited vars, force SO4, SRB

# %% [markdown]
# ### i) select input data
#
# y_var: 'CH4_logn1'; x_vars, x_vars0

# %%
# Def y var
y_var <- 'CH4_logn1'

# %%
# DEFINE various X data sets:

# Most VARS IN, no ratios etc.
x_vars <-xvars1                     # x_vars

# ALL VARS IN, w/ ratios, remove CH4 permutations
drop2 <- c(drop_gas, drop_pw)
#drop_2cl <- c(drop2, "Cl")                  # also drop Cl!

max_vars <- xvars0[!xvars0 %in% drop2]
#max_vars <- xvars0[!xvars0 %in% drop_2cl]   # also drop Cl!

x_vars0 <- max_vars

# %%
x_vars0
# Out:
#  [1] "CO2_mg_m2_h" "Bulk_dens"   "H2O_FPS"     "pH"          "C"
#  [6] "N"           "P"           "CN"          "NP"          "NO3_N"
# [11] "NH4_N"       "Olsen_P"     "NO3_NH4"     "NP_ext"      "Salinity.x"
# [16] "Cl"          "SO4"         "CH4_H2"      "CH4_ac"      "MOB_I"
# [21] "MOB_II"      "MOB_IIa"     "MeOB"        "AOA"         "AOB"
# [26] "NOB"         "Anamx"       "SOxB"        "SRB_syn"     "SRB"
# [31] "FeOB"        "FeRB"        "Actino"      "Chlorf"      "Firmic"
# [36] "AO_NOB"      "NOB_AO"      "mcr_pmo"     "pmo_mcr"

# %%
# x_CO2_C

# %% [markdown]
# ### ii) create lasso objects, coef plots for diff scenarios
#
# hard filter SO4, force in SRB

# %%
# all vars with RATIOS, complete, nothing held back
CH4_delt_ALL <- lasso_mod_plot(y_var, x_vars0, Guild_CH4_dS, guild_colors, plot_title = 'CH4_delta: all vars')

# all vars
CH4_delt_all <- lasso_mod_plot(y_var, x_vars, Guild_CH4_dS, guild_colors, plot_title = 'CH4_delta: all vars')

# force in SO4
CH4_delt_fSO4 <- CH4_delt_all 

# force in SRB
CH4_delt_fSRB <- lasso_mod_plot(y_var, x_vars, Guild_CH4_dS, guild_colors, 
                             force_in = c('SRB'), plot_title = 'CH4_delta: force SRB')

# all vars
CH4_delt_fmobac <- lasso_mod_plot(y_var, x_vars, Guild_CH4_dS, guild_colors, 
                             force_in = c('MOB_IIa, CH4_ac'), plot_title = 'CH4_delta: all vars')
# Out:
# [1] "best_lambda: 0.0394"
#      R2  RMSE
# 1 0.872 0.383
# [1] "best_lambda: 0.0321"
#      R2  RMSE
# 1 0.863 0.393
# [1] "best_lambda: 0.0275"
#      R2  RMSE
# 1 0.863 0.393
# [1] "best_lambda: 0.0321"
#      R2  RMSE
# 1 0.863 0.393

# %% [markdown]
# ### iii) get SEM models, filtered, lists w plots

# %%
# all vars
CH4_delt_all_sem <- lasso_obj_to_sem_select_plots(CH4_delt_all, 'CH4_logn1', Guild_CH4_dS, guild_colors,
                                         nbest = 3, keep_filt = 0.5, resid_0filt = TRUE,  # sem filts
                                         heat_filt = 0.7, k_clusts = 3)

# ALL vars w/ ratios, taxa (min call)
CH4_delt_ALL_sem <- lasso_obj_to_sem_select_plots(CH4_delt_ALL, 'CH4_logn1', Guild_CH4_dS, guild_colors)
# Out:
# `geom_smooth()` using formula 'y ~ x'
#
# `geom_smooth()` using formula 'y ~ x'

# %%
# forced SO4
CH4_delt_fSO4_sem <- lasso_obj_to_sem_select_plots(CH4_delt_fSO4, 'CH4_logn1', Guild_CH4_dS, guild_colors,
                                         force_filt = 'SO4', nbest = 3, keep_filt = 0.5, resid_0filt = TRUE,  # sem filts
                                         heat_filt = 0.7, k_clusts = 3)
# Out:
# `geom_smooth()` using formula 'y ~ x'

# %%
# forced SRB
CH4_delt_fSRB_sem <- lasso_obj_to_sem_select_plots(CH4_delt_fSRB, 'CH4_logn1', Guild_CH4_dS, guild_colors,
                                         force_filt = 'SRB', nbest = 3, keep_filt = 0.5, resid_0filt = TRUE,  # sem filts
                                         heat_filt = 0.7, k_clusts = 3)

                                         # see more models   
                                         #force_filt = 'SRB', nbest = 5, keep_filt = 0.5, resid_0filt = FALSE,  # sem filts
                                         #heat_filt = 0.5, k_clusts = 5)
# Out:
# `geom_smooth()` using formula 'y ~ x'

# %%
# forced SRB
CH4_delt_f_mobac_sem <- lasso_obj_to_sem_select_plots(CH4_delt_fmobac, 'CH4_logn1', Guild_CH4_dS, guild_colors,
                                         force_filt = c('MOB_IIa','CH4_ac'), nbest = 3, keep_filt = 0.5, resid_0filt = TRUE,  # sem filts
                                         heat_filt = 0.7, k_clusts = 3)
# Out:
# `geom_smooth()` using formula 'y ~ x'

# %% [markdown]
# ### iv) get model comparison plots

# %%
options(repr.plot.width=12, repr.plot.height= 3) # plot dims for combined plots

# %%
# CH4_delt_all_sem$plot

# %%
options(repr.plot.width=12, repr.plot.height= 3) # plot dims for combined plots

CH4_delt_ALL_sem$plot
CH4_delt_all_sem$plot
CH4_delt_fSO4_sem$plot
CH4_delt_fSRB_sem$plot
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %%
CH4_delt_f_mobac_sem$plot
# Out:
# plot without title

# %% [markdown]
# ## b) CH4 model: No CO2 and CO2/C models

# %% [markdown]
# ### i) select input data
#
# y_var: 'CH4_logn1'; x_vars, x_vars0, x_noCO2, x_CO2_C

# %%
# Def y var
y_var <- 'CH4_logn1'

# %%
# DEFINE various X data sets:

# Most VARS IN, no ratios etc.
#x_vars <-xvars1                     # x_vars

# ALL VARS IN, w/ ratios, remove CH4 permutations
#max_vars <- xvars0[!xvars0 %in% drop_gas]
#x_vars0 <- max_vars                                  

# no CO2
CO2 <- 'CO2_mg_m2_h'
x_noCO2 <- x_vars[!x_vars %in% CO2]

# no CO2.2 - drop MOBII, wrong weight
x_noCO2.2 <- drop_from_list('MOB_II', x_noCO2)

# replace CO2 w CO2_C
x_CO2_C <- c(x_noCO2, 'CO2_soilC_mg_g_d')

# %% [raw]
# x_noCO2.2
# # x_CO2_C

# %% [markdown]
# ### ii) create lasso objects, coef plots for diff scenarios
#
# hard filter SO4, force in SRB

# %%
options(repr.plot.width=4, repr.plot.height= 3)  # plot dims for coeff plots

# %%
# no CO2
CH4_delt_xCO2 <- lasso_mod_plot(y_var, x_noCO2, Guild_CH4_dS, guild_colors, plot_title = 'CH4_delta: noCO2')

# no CO2.2 -- drop MOBII
CH4_delt_xCO2.2 <- lasso_mod_plot(y_var, x_noCO2.2, Guild_CH4_dS, guild_colors, plot_title = 'CH4_delta: noCO2')

# CO2/C instead of CO2
CH4_delt_CO2C <- lasso_mod_plot(y_var, x_CO2_C, Guild_CH4_dS, guild_colors, plot_title = 'CH4_delta: CO2/C')
# Out:
# [1] "best_lambda: 0.0511"
#      R2  RMSE
# 1 0.701 0.584
# [1] "best_lambda: 0.0561"
#      R2  RMSE
# 1 0.678 0.607
# [1] "best_lambda: 0.0267"
#      R2  RMSE
# 1 0.866 0.391

# %% [raw]
# # CH4_delt_xCO2$coef_plot

# %% [raw]
#  #CH4_delt_CO2C$coef_plot

# %% [markdown]
# ### iii) get SEM models, filtered, lists w plots)

# %%
# no CO2 - had to drop heat filt down to 0.65, NO resid filter!
CH4_delt_xCO2_sem <- lasso_obj_to_sem_select_plots(CH4_delt_xCO2, 'CH4_logn1', Guild_CH4_dS, guild_colors,
                                         nbest = 3, keep_filt = 0.5, resid_0filt = FALSE,  # sem filts
                                         heat_filt = 0.65, k_clusts = 4)

# no CO2.2 - had to drop heat filt down to 0.65
CH4_delt_xCO2.2_sem <- lasso_obj_to_sem_select_plots(CH4_delt_xCO2.2, 'CH4_logn1', Guild_CH4_dS, guild_colors,
                                         nbest = 3, keep_filt = 0.5, resid_0filt = FALSE,  # sem filts
                                         heat_filt = 0.5, k_clusts = 4)

# CO2/C
CH4_delt_CO2C_sem <- lasso_obj_to_sem_select_plots(CH4_delt_CO2C, 'CH4_logn1', Guild_CH4_dS, guild_colors,
                                         nbest = 3, keep_filt = 0.5, resid_0filt = TRUE,  # sem filts
                                         heat_filt = 0.7, k_clusts = 4)
# Out:
# `geom_smooth()` using formula 'y ~ x'
#
# `geom_smooth()` using formula 'y ~ x'
#
# `geom_smooth()` using formula 'y ~ x'

# %% [markdown]
# ### iv) get model comparison plots

# %%
options(repr.plot.width=12, repr.plot.height= 3) # plot dims for combined plots

# %%
# CH4_delt_ALL_sem$plot
CH4_delt_xCO2_sem$plot
CH4_delt_xCO2.2_sem$plot 
CH4_delt_CO2C_sem$plot
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ## c) MOB_IIa models: LASSO feature selection

# %% [markdown]
# ### i) select input data
#
# y_var = 'MOB_IIa'
#
# - x_MOBIIa.3  (removed other guilds, see also .1-2)
# - x_MOBIIa.4  (removed N, C, P, dominating w/o mech)

# %%
#x_vars <- x_vars[!x_vars %in% 'Cl']   # DROP Cl
#x_vars <- x_vars[!x_vars %in% 'Salinity.x']   # DROP Cl
x_vars
# Out:
#  [1] "CO2_mg_m2_h" "Bulk_dens"   "H2O_FPS"     "pH"          "C"
#  [6] "N"           "P"           "NO3_N"       "NH4_N"       "Olsen_P"
# [11] "Salinity.x"  "Cl"          "SO4"         "CH4_H2"      "CH4_ac"
# [16] "MOB_I"       "MOB_II"      "MOB_IIa"     "AOA"         "AOB"
# [21] "NOB"         "SRB_syn"     "SRB"         "FeRB"

# %%
# Initialize x vars for MOB_IIa
MOBIIa_drop.1 <- c('CO2_mg_m2_h','MOB_IIa','SRB_syn','SRB','FeRB','Olsen_P','P')
x_MOBIIa.1 <- drop_from_list(MOBIIa_drop.1 , x_vars)                   # init list

MOBIIa_drop.2 <- c('MOB_I','MOB_II')                                   # corr not mech (wrong sign)
x_MOBIIa.2 <- drop_from_list(MOBIIa_drop.2, x_MOBIIa.1)

MOBIIa_drop.3 <- c('CH4_ac','CH4_H2')                                  # corr not mech (wrong sign)
x_MOBIIa.3 <- drop_from_list(MOBIIa_drop.3, x_MOBIIa.2)

MOBIIa_drop.4 <- c('N', 'C', 'P')                                      # overwhelm signal, sequential
x_MOBIIa.4 <- drop_from_list(MOBIIa_drop.4, x_MOBIIa.3)

#x_MOBIIa.3r <- c(x_MOBIIa.3, 'CN','NP','NO3_NH4','NP_ext')
# x_CH4ac.3 <- c(x_CH4ac.2,'CN','NP','NO3_NH4','NP_ext')

# %% [markdown]
# ### ii) create lasso objects, coef plots for diff scenarios

# %%
# all vars
MOBIIa_delt_all <- lasso_mod_plot('MOB_IIa', x_MOBIIa.1, Guild_CH4_dS, guild_colors, plot_title = 'MOBIIa_delta1: all vars')

# drop other guilds
MOBIIa_delt_ng <- lasso_mod_plot('MOB_IIa', x_MOBIIa.3, Guild_CH4_dS, guild_colors, plot_title = 'MOBIIa_delta3: no_troph/gen')

# force in AOA, AOB to ng
MOBIIa_delt_fAOANOB <- lasso_mod_plot('MOB_IIa', x_MOBIIa.3, Guild_CH4_dS, guild_colors, 
                             force_in = c('AOA', 'NOB'), plot_title = 'MOBIIa_delta3: force AOA, NOB')

# drop soil totals
MOBIIa_delt_ngt <- lasso_mod_plot('MOB_IIa', x_MOBIIa.4, Guild_CH4_dS, guild_colors, plot_title = 'MOBIIa_delta4: ng/totals')

# force in AOA, AOB to ng
#MOBIIa_delt_f3r<- lasso_mod_plot('MOB_IIa', x_MOBIIa.3r, Guild_CH4_dS, guild_colors, 
#                             force_in = c('AOA', 'NOB'), plot_title = 'MOBIIa_delta3r: force AOA, NOB, ratios')

# 5th iter data
#MOBIIa_delt_ngt <- lasso_mod_plot('MOB_IIa', x_MOBIIa.5, Guild_CH4_dS, guild_colors, plot_title = 'MOBIIa_delta5: ng/totals')
# Out:
# [1] "best_lambda: 0.018"
#      R2  RMSE
# 1 0.846 0.391
# [1] "best_lambda: 0.0018"
#      R2  RMSE
# 1 0.854 0.379
# [1] "best_lambda: 0.0016"
#      R2  RMSE
# 1 0.854 0.379
# [1] "best_lambda: 0.0136"
#      R2  RMSE
# 1 0.734 0.512

# %%
mobIIa_lassos <- list("MOBIIa_delt_all", "MOBIIa_delt_ng", "MOBIIa_delt_fAOANOB", 
                      "MOBIIa_delt_ngt") #, "MOBIIa_delt_f3r")

# %%
options(repr.plot.width = 15, repr.plot.height = 3)

plot_lasso_obj_list(mobIIa_lassos)
# Out:
# plot without title

# %% [markdown]
# ### iii) get SEM models, filtered, lists w plots

# %%
#"MOBIIa_delt_all", "MOBIIa_delt_ng", "MOBIIa_delt_fAOANOB", "MOBIIa_delt_ngt"

# %%
# MOB_IIa no CH4 guilds
MOBIIa_delt_ng_sem <- lasso_obj_to_sem_select_plots(MOBIIa_delt_ng, 'MOB_IIa', Guild_CH4_dS, guild_colors,
                                         nbest = 3, keep_filt = 0.5, resid_0filt = TRUE,  # sem filts
                                         heat_filt = 0.65, k_clusts = 4)

# MOB_IIa no CH4 guilds
MOBIIa_delt_fAOANOB_sem <- lasso_obj_to_sem_select_plots(MOBIIa_delt_fAOANOB, 'MOB_IIa', Guild_CH4_dS, guild_colors,
                                         force_filt = c('AOA','NOB'), nbest = 3, keep_filt = 0.5, resid_0filt = TRUE,  # sem filts
                                         heat_filt = 0.65, k_clusts = 1)

# MOB_IIa no CH4 guilds
MOBIIa_delt_ngt_sem <- lasso_obj_to_sem_select_plots(MOBIIa_delt_ngt, 'MOB_IIa', Guild_CH4_dS, guild_colors,
                                         nbest = 3, keep_filt = 0.5, resid_0filt = TRUE,  # sem filts
                                         heat_filt = 0.65, k_clusts = 1)
# Out:
# `geom_smooth()` using formula 'y ~ x'
#
# `geom_smooth()` using formula 'y ~ x'
#
# `geom_smooth()` using formula 'y ~ x'

# %% [markdown]
# ### iv) get model comparison plots

# %%
MOBIIa_delt_ng_sem$plot
MOBIIa_delt_fAOANOB_sem$plot
MOBIIa_delt_ngt_sem$plot
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# #####

# %% [markdown]
# ## d) CH4_ac models: LASSO feature selection

# %% [markdown]
# ### i) select input data

# %%
#x_vars
#x_vars <- x_vars[!x_vars %in% 'Cl']   # DROP Cl
#x_vars <- x_vars[!x_vars %in% 'Salinity.x']   # DROP Cl
x_vars
# Out:
#  [1] "CO2_mg_m2_h" "Bulk_dens"   "H2O_FPS"     "pH"          "C"
#  [6] "N"           "P"           "NO3_N"       "NH4_N"       "Olsen_P"
# [11] "Salinity.x"  "Cl"          "SO4"         "CH4_H2"      "CH4_ac"
# [16] "MOB_I"       "MOB_II"      "MOB_IIa"     "AOA"         "AOB"
# [21] "NOB"         "SRB_syn"     "SRB"         "FeRB"

# %%
# Initialize x vars for CH4_ac
CH4ac_drop.1 <- c('CO2_mg_m2_h','CH4_ac','CH4_H2','MOB_I','MOB_II','MOB_IIa','Olsen_P','P')       # first drop CH4 related
x_CH4ac.1 <- drop_from_list(CH4ac_drop.1, x_vars)                   # init list

# next drop N cycling microbes
CH4ac_drop.2 <- c('AOA', 'AOB', 'NOB')                                 
x_CH4ac.2 <- drop_from_list(CH4ac_drop.2, x_CH4ac.1) 

# then add chem ratios
#x_CH4ac.3 <- c(x_CH4ac.2, drop_ratios)                        - didn't work, unlist??
x_CH4ac.3 <- c(x_CH4ac.2,'CN','NP','NO3_NH4','NP_ext')                             # NO CP in data!!
 
# last, add some PW components
x_CH4ac.4 <- c(x_CH4ac.3, "DOC_mg_L", "Fe_pw")
#x_CH4ac.3 <- c('Bulk_dens','H2O_FPS','pH','C','Salinity.x','SO4','SRB_syn','SRB','FeRB', 'DOC_mg_L','Fe_pw')

# drop hard to explain vars

CH4ac_drop.5 <- c('NP', 'N')   
x_CH4ac.5 <- drop_from_list(CH4ac_drop.5, x_CH4ac.4)

# %% [raw]
# x_CH4ac.3

# %% [raw]
# names(Guild_CH4_dS)

# %% [markdown]
# ### ii) create lasso objects, coef plots for diff scenarios

# %%
CH4ac_delta.1 <- lasso_mod_plot('CH4_ac', x_CH4ac.1, Guild_CH4_dS, guild_colors, plot_title = 'CH4ac_delta1: init vars')
CH4ac_delta.2 <- lasso_mod_plot('CH4_ac', x_CH4ac.2, Guild_CH4_dS, guild_colors, plot_title = 'CH4ac_delta2: no N guild')

CH4ac_delta.3 <- lasso_mod_plot('CH4_ac', x_CH4ac.3, Guild_CH4_dS, guild_colors, plot_title = 'CH4ac_delta3: add ratios')
CH4ac_delta.4 <- lasso_mod_plot('CH4_ac', x_CH4ac.4, Guild_CH4_dS, guild_colors, plot_title = 'CH4ac_delta4: add pw')

# Force SRB, FeRB into x4 (max vars)
CH4ac_d_fSrFeRB <- lasso_mod_plot('MOB_IIa', x_CH4ac.5, Guild_CH4_dS, guild_colors, 
                             force_in = c('FeRB','SRB_syn'), plot_title = 'CH4ac_delta4_fSrFeRB')
# Out:
# [1] "best_lambda: 0.0192"
#      R2  RMSE
# 1 0.755 0.495
# [1] "best_lambda: 0.0083"
#      R2  RMSE
# 1 0.753 0.494
# [1] "best_lambda: 0.0276"
#      R2  RMSE
# 1 0.748 0.504
# [1] "best_lambda: 0.0158"
#      R2  RMSE
# 1 0.781 0.466
# [1] "best_lambda: 0.0066"
#      R2 RMSE
# 1 0.869 0.36

# %%
options(repr.plot.width = 15, repr.plot.height = 3)
ch4ac_lassos = c('CH4ac_delta.1','CH4ac_delta.2','CH4ac_delta.3','CH4ac_delta.4', 'CH4ac_d_fSrFeRB')

plot_lasso_obj_list(ch4ac_lassos)
# Out:
# plot without title

# %% [raw]
# options(repr.plot.width = 4, repr.plot.height = 3)
# CH4ac_delta.1$coef_plot
# CH4ac_delta.2$coef_plot
# CH4ac_delta.3$coef_plot
# CH4ac_delta.4$coef_plot

# %% [markdown]
# ### iii) get SEM models, filtered, lists w plots

# %%
# MOB_IIa no CH4 guilds
CH4ac_delta.1_sem <- lasso_obj_to_sem_select_plots(CH4ac_delta.1, 'CH4_ac', Guild_CH4_dS, guild_colors,
                                         nbest = 3, keep_filt = 0.5, resid_0filt = TRUE,  # sem filts
                                         heat_filt = 0.65, k_clusts = 4)

CH4ac_delta.2_sem <- lasso_obj_to_sem_select_plots(CH4ac_delta.2, 'CH4_ac', Guild_CH4_dS, guild_colors,
                                         nbest = 3, keep_filt = 0.5, resid_0filt = TRUE,  # sem filts
                                         heat_filt = 0.65, k_clusts = 4)

CH4ac_delta.3_sem <- lasso_obj_to_sem_select_plots(CH4ac_delta.3, 'CH4_ac', Guild_CH4_dS, guild_colors,
                                         nbest = 3, keep_filt = 0.5, resid_0filt = TRUE,  # sem filts
                                         heat_filt = 0.65, k_clusts = 4)

CH4ac_delta.4_sem <- lasso_obj_to_sem_select_plots(CH4ac_delta.4, 'CH4_ac', Guild_CH4_dS, guild_colors,
                                         nbest = 3, keep_filt = 0.5, resid_0filt = TRUE,  # sem filts
                                         heat_filt = 0.65, k_clusts = 4)

CH4ac_delta_f_sem <- lasso_obj_to_sem_select_plots(CH4ac_d_fSrFeRB, 'CH4_ac', Guild_CH4_dS, guild_colors,
                                         nbest = 3, keep_filt = 0.5, resid_0filt = TRUE,  # sem filts
                                         heat_filt = 0.65, k_clusts = 4)


#CH4ac_delta_f_sem <- lasso_obj_to_sem_select_plots(CH4ac_d_fSrFeRB, 'CH4_ac', Guild_CH4_dS, guild_colors,
#                                         nbest = 3, keep_filt = 0.5, resid_0filt = TRUE,  # sem filts
#                                         heat_filt = 0.65, k_clusts = 4)
# Out:
# `geom_smooth()` using formula 'y ~ x'
#
# `geom_smooth()` using formula 'y ~ x'
#
# `geom_smooth()` using formula 'y ~ x'
#
# `geom_smooth()` using formula 'y ~ x'
#
# `geom_smooth()` using formula 'y ~ x'

# %% [markdown]
# ### iv) get model comparison plots

# %%
options(repr.plot.width=12, repr.plot.height= 3) # plot dims for combined plotsCH4ac_delta.1_sem$plot
CH4ac_delta.2_sem$plot
CH4ac_delta.3_sem$plot
CH4ac_delta.4_sem$plot
CH4ac_delta_f_sem$plot
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ### 4) save / load R object data

# %%
# save.image(file = "CH4_Delta_SEM_models_noClP.RData")

# %% [raw]
# load("CH4_Delta_SEM_models_noClP.RData")

# %% [raw]
# # test loading
# CH4ac_delta_f_sem$plot

# %% [markdown]
# # 4) DELTA composite SEM branched model CH4 workflows

# %% [markdown]
# - leaning on v1.08 here, copy and simplify.
# - test do branches need to be run first?  forumulas composited?

# %%
# Define composite variable assignments
CH4_gen <- c("CH4_ac", "CH4_H2", "CO2_mg_m2_h", "Salinity.x", "SO4", "SRB", "FeRB")#, "NP")

CH4_ox <- c("MOB_IIa", "MOB_I", "MOB_II", "Bulk_dens", "H2O_FPS", 
            "N", "AOB", "AOA", "NOB", "NO3_N", "NH4_N", "NO3_NH4")

composite_sets <- c("CH4_gen", "CH4_ox")

# %% [markdown]
# ### a) prepare data

# %% [markdown]
# #### i) tree base - all CH4 models

# %% [raw]
# # rename models and "model" row prefix
# CH4_da_base_m <- CH4_delt_all_sem$filt_models                   # get filtered models
# CH4_da_base_m$model <- paste0("dch4a." ,CH4_da_base_m$model)

# %% [raw]
# # SEM tree base - Delta all
# #CH4_da_base_m <- get_sem_models_add_prefix(CH4_delt_all_sem, models = "filt_models", prefix = "dch4a.")
# #CH4_da_base_m <- rename_formula_col_as_yvar(results_table, formula_col = 'form', fxn_operator = '~')
# CH4_da_tree_c <- get_composites_model_table(CH4_da_base_m, composite_sets, assign_other = "y_var",#)"CH4_gen",
#                            no_int = FALSE, compos_fail_collapse_all = TRUE)

# %%
#CH4_da_tree_c

# %% [raw]
# # pick base models
# CH4_da_tree_s <- data.frame(CH4_da_tree_c[1:2,])   # picking first 6 models, others look funny, don't run?
# #tree_base <- CH4_da_tree_s
# CH4_da_tree_s

# %% [raw]
# # try running models -
# CH4_da_tree_r <- suppressWarnings(run_compare_sem_models(CH4_da_tree_s, Guild_CH4_ds,
#                                             estimator = "mlm", keep_mod_descr = c("model_out","model")))

# %% [markdown]
# ##### x) failing updates, revert to v0.11 section 14) composite SEM test (above)

# %%
CH4_da_base_m <- get_sem_models_add_prefix(CH4_delt_all_sem, models = "filt_models", prefix = "dch4a.")
#CH4_da_base_m <- rename_formula_col_as_yvar(CH4_da_base_m, formula_col = 'form', fxn_operator = '~')
CH4_da_base_m
# Out:
#    model     aic     bic     npar R2
# 12 dch4a.107 859.645 905.307 21   0.848
# 11 dch4a.69  761.271 793.886 15   0.832
# 10 dch4a.34  634.209 655.953 10   0.813
# 9  dch4a.112 921.086 966.748 21   0.857
# 8  dch4a.109 907.108 952.771 21   0.854
# 7  dch4a.67  741.549 774.164 15   0.836
# 6  dch4a.35  643.430 665.174 10   0.810
# 5  dch4a.10  494.026 507.072  6   0.670
# 4  dch4a.66  738.237 770.852 15   0.802
# 3  dch4a.8   485.923 498.969  6   0.726
# 2  dch4a.31  619.570 641.314 10   0.759
# 1  dch4a.13  504.298 517.345  6   0.622
#    form                                                        all_sig n_pred
# 12 CH4_logn1  ~ CO2_mg_m2_h + CH4_ac + MOB_IIa + Bulk_dens + N 1       5
# 11 CH4_logn1  ~ CO2_mg_m2_h + CH4_ac + MOB_IIa + Bulk_dens     1       4
# 10 CH4_logn1  ~ CO2_mg_m2_h + CH4_ac + MOB_IIa                 1       3
# 9  CH4_logn1  ~ CO2_mg_m2_h + CH4_ac + Bulk_dens + SO4 + N     1       5
# 8  CH4_logn1  ~ CO2_mg_m2_h + CH4_ac + Bulk_dens + AOB + N     1       5
# 7  CH4_logn1  ~ CO2_mg_m2_h + CH4_ac + Bulk_dens + N           1       4
# 6  CH4_logn1  ~ CO2_mg_m2_h + CH4_ac + Bulk_dens               1       3
# 5  CH4_logn1  ~ CO2_mg_m2_h + CH4_ac                           1       2
# 4  CH4_logn1  ~ CO2_mg_m2_h + MOB_IIa + Bulk_dens + N          1       4
# 3  CH4_logn1  ~ CO2_mg_m2_h + MOB_IIa                          1       2
# 2  CH4_logn1  ~ CO2_mg_m2_h + Bulk_dens + N                    1       3
# 1  CH4_logn1  ~ CO2_mg_m2_h + MOB_II                           1       2
#    aic_glm   bic_glm   aicc_glm  resid vip_indx
# 12  82.73206  97.95277  84.69697 0.089  1
# 11  87.26881 100.31514  88.71709 0.143  2
# 10  92.14750 103.01944  93.16445 0.214  3
# 9   78.77740  93.99811  80.74231 0.055  4
# 8   80.01750  95.23821  81.98241 0.062  5
# 7   85.64456  98.69088  87.09283 0.161  6
# 6   93.31316 104.18510  94.33011 0.204  7
# 5  127.17383 135.87138 127.84049 0.170  8
# 4   97.91508 110.96141  99.36336 0.129  9
# 3  115.01462 123.71217 115.68128 0.231 10
# 2  108.83270 119.70464 109.84965 0.170 11
# 1  135.98897 144.68652 136.65564 0.114 12

# %%
# SEM tree base - Delta all
#CH4_da_base_m <- get_sem_models_add_prefix(CH4_delt_all_sem, models = "filt_models", prefix = "dch4a.")
#CH4_da_base_m <- rename_formula_col_as_yvar(results_table, formula_col = 'form', fxn_operator = '~')
CH4_da_tree_c <- get_composites_model_table(CH4_da_base_m, composite_sets, assign_other = "y_var",#)"CH4_gen", 
                           no_int = FALSE, compos_fail_collapse_all = TRUE)
#CH4_da_base_m

# %%
# try running models - 
CH4_da_tree_r <- suppressWarnings(run_compare_sem_models(CH4_da_tree_s, Guild_CH4_ds, 
                                            estimator = "mlm", keep_mod_descr = c("model_out","model")))
# Out:
# Error in assign(sem_names[[i]], sems[[i]], envir = .GlobalEnv): invalid first argument
# Traceback:
#
# 1. suppressWarnings(run_compare_sem_models(CH4_da_tree_s, Guild_CH4_ds,
#  .     estimator = "mlm", keep_mod_descr = c("model_out", "model")))
# 2. withCallingHandlers(expr, warning = function(w) invokeRestart("muffleWarning"))
# 3. run_compare_sem_models(CH4_da_tree_s, Guild_CH4_ds, estimator = "mlm",
#  .     keep_mod_descr = c("model_out", "model"))
# 4. sem_table_run_assign_P(mod_table, data, estimator, ncores = ncores,
#  .     print_failed = print_failed)
# 5. assign(sem_names[[i]], sems[[i]], envir = .GlobalEnv)

# %%
# SEM tree base - Delta all
#CH4_da_base_m <- CH4_delt_all_sem$filt_models         # source, LASS SEM FILTERED models (obj)
#CH4_da_base_m$model <- paste0("ch4da." ,CH4_da_base_m$model)

# Get composites for MODEL
CH4_da_tree_c <- get_composites_model_table(CH4_da_base_m, composite_sets, assign_other = "y_var",#)"CH4_gen", 
                           no_int = FALSE, compos_fail_collapse_all = FALSE)

#CH4_da_tree_c #-- note all but below fail compositing

# pick base models
CH4_da_tree_s <- CH4_da_tree_c[1:5,]   # picking first 6 models, others look funny, don't run? 
#tree_base <- CH4_da_tree_s
CH4_da_tree_s
# Out:
#   model_out     model     CH4_logn1
# 1 sem.dch4a.107 dch4a.107 CH4_logn1 ~ CH4_gen + CH4_ox
# 2 sem.dch4a.69  dch4a.69  CH4_logn1 ~ CH4_gen + CH4_ox
# 4 sem.dch4a.112 dch4a.112 CH4_logn1 ~ CH4_gen + CH4_ox
# 5 sem.dch4a.109 dch4a.109 CH4_logn1 ~ CH4_gen + CH4_ox
# 6 sem.dch4a.67  dch4a.67  CH4_logn1 ~ CH4_gen + CH4_ox
#   CH4_gen                                 CH4_ox
# 1 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 2 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 4 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4 CH4_ox <~ 1*Bulk_dens + N
# 5 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N + AOB
# 6 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N
#   comp_failed
# 1
# 2
# 4
# 5
# 6
#   formula
# 1 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 2 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens
# 4 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*Bulk_dens + N
# 5 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N + AOB
# 6 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N

# %%
CH4_da_tree_s$formula
# Out:
# [1] "CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N"
# [2] "CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens"
# [3] "CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*Bulk_dens + N"
# [4] "CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N + AOB"
# [5] "CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N"

# %% [raw]
# # try running models -
# CH4_mod_fch4.2_r <- suppressWarnings(run_compare_sem_models(CH4_mod_fch4.2_c, Guild_CH4_ds,
#                                             estimator = "mlm", keep_mod_descr = c("model_out","model")))

# %% [raw]
# # other base models possible? -- NO, next try CO2/C base
# sem_delta_base <- run_sem_model_summary(CH4_da_tree_s, Guild_CH4_dS, sort_by = 'pvalue', sort_cutoff = 0.00)
# sem_delta_base

# %%
# CH4 base model with forced MOB_IIa/CH4_ac (not filtered)
CH4_fg_base_m <-CH4_delt_f_mobac_sem$sem_models                # all models
CH4_fg_base_m$model <- paste0("ch4fg." ,CH4_fg_base_m$model)

# Get composites for MODEL
CH4_fg_tree_c <- get_composites_model_table(CH4_fg_base_m, composite_sets, assign_other = "CH4_gen", 
                           no_int = FALSE, compos_fail_collapse_all = TRUE)

#CH4_fg_tree_c
CH4_fg_tree_s <- CH4_fg_tree_c[1:7,]
CH4_fg_tree_s
# Out:
#   model_out    model    CH4_logn1
# 1 sem.ch4fg.7  ch4fg.7  CH4_logn1 ~ CH4_gen + CH4_ox
# 2 sem.ch4fg.9  ch4fg.9  CH4_logn1 ~ CH4_gen + CH4_ox
# 3 sem.ch4fg.8  ch4fg.8  CH4_logn1 ~ CH4_gen + CH4_ox
# 4 sem.ch4fg.6  ch4fg.6  CH4_logn1 ~ CH4_gen + CH4_ox
# 5 sem.ch4fg.3  ch4fg.3  CH4_logn1 ~ CH4_gen + CH4_ox
# 7 sem.ch4fg.10 ch4fg.10 CH4_logn1 ~ CH4_gen + CH4_ox
# 8 sem.ch4fg.5  ch4fg.5  CH4_logn1 ~ CH4_gen + CH4_ox
#   CH4_gen                                 CH4_ox
# 1 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + pH  CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 2 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4 CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 3 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens + AOB
# 4 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 5 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 7 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4 CH4_ox <~ 1*MOB_IIa + H2O_FPS
# 8 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + AOB
#   comp_failed
# 1
# 2
# 3
# 4
# 5
# 7
# 8
#   formula
# 1 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + pH\nCH4_ox <~ 1*MOB_IIa + Bulk_dens
# 2 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*MOB_IIa + Bulk_dens
# 3 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + AOB
# 4 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 5 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens
# 7 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*MOB_IIa + H2O_FPS
# 8 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + AOB

# %%
# tree_base <- CH4_fg_tree_s
tree_base <- CH4_da_tree_s

# %% [markdown]
# #### ii) tree base with CO2/C models

# %%
# CH4 base model with forced MOB_IIa/CH4_ac (not filtered)
CH4_co2c_base_m <-CH4_delt_CO2C_sem$filt_models               # all models
CH4_co2c_base_m$model <- paste0("ch4co2cD." ,CH4_co2c_base_m$model)

# Get composites for MODEL
CH4_co2c_tree_c <- get_composites_model_table(CH4_co2c_base_m, composite_sets, assign_other = "CH4_gen", 
                           no_int = FALSE, compos_fail_collapse_all = FALSE)
#CH4_co2c_tree_c
CH4_co2c_tree_s <- CH4_co2c_tree_c[1:5,]
CH4_co2c_tree_c

ch4_co2_pick <- c(1, 6, 7, 8, 18)
CH4_co2c_tree_s2 <- CH4_co2c_tree_c[ch4_co2_pick,]
# tree_base <- CH4_co2c_tree_s2
# Out:
#    model_out        model        CH4_logn1
# 1  sem.ch4co2cD.91  ch4co2cD.91  CH4_logn1 ~ CH4_gen + CH4_ox
# 2  sem.ch4co2cD.104 ch4co2cD.104 CH4_logn1 ~ CH4_gen + CH4_ox
# 3  sem.ch4co2cD.105 ch4co2cD.105 CH4_logn1 ~ CH4_gen + CH4_ox
# 4  sem.ch4co2cD.64  ch4co2cD.64  CH4_logn1 ~ CH4_gen + CH4_ox
# 5  sem.ch4co2cD.67  ch4co2cD.67  CH4_logn1 ~ CH4_gen + CH4_ox
# 6  sem.ch4co2cD.37  ch4co2cD.37  CH4_logn1 ~ CH4_gen + Bulk_dens
# 7  sem.ch4co2cD.65  ch4co2cD.65  CH4_logn1 ~ CO2_soilC_mg_g_d + CH4_ox
# 8  sem.ch4co2cD.34  ch4co2cD.34  CH4_logn1 ~ CO2_soilC_mg_g_d + CH4_ox
# 9  sem.ch4co2cD.41  ch4co2cD.41  CH4_logn1 ~ CH4_gen + MOB_IIa
# 12 sem.ch4co2cD.22  ch4co2cD.22  CH4_logn1 ~ CH4_gen + CH4_ox
# 10 sem.ch4co2cD.15  ch4co2cD.15  CH4_logn1  ~ CO2_soilC_mg_g_d + MOB_IIa
# 11 sem.ch4co2cD.20  ch4co2cD.20  CH4_logn1  ~ CH4_ac + H2O_FPS
#    CH4_gen
# 1  CH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d
# 2  CH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d + pH
# 3  CH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d
# 4  CH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d
# 5  CH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d
# 6  CH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d
# 7
# 8
# 9  CH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d
# 12
# 10
# 11
#    CH4_ox                              comp_failed
# 1  CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 2  CH4_ox <~ 1*Bulk_dens + N
# 3  CH4_ox <~ 1*Bulk_dens + N + AOB
# 4  CH4_ox <~ 1*Bulk_dens + N
# 5  CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 6                                      CH4_ox
# 7  CH4_ox <~ 1*MOB_IIa + Bulk_dens + N CH4_gen
# 8  CH4_ox <~ 1*Bulk_dens + N           CH4_gen
# 9                                      CH4_ox
# 12 CH4_ox <~ 1*H2O_FPS + N             CH4_gen
# 10                                     CH4_gen, CH4_ox
# 11                                     CH4_gen, CH4_ox
#    formula
# 1  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 2  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d + pH\nCH4_ox <~ 1*Bulk_dens + N
# 3  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d\nCH4_ox <~ 1*Bulk_dens + N + AOB
# 4  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d\nCH4_ox <~ 1*Bulk_dens + N
# 5  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d\nCH4_ox <~ 1*MOB_IIa + Bulk_dens
# 6  CH4_logn1 ~ CH4_gen + Bulk_dens\nCH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d\n
# 7  CH4_logn1 ~ CO2_soilC_mg_g_d + CH4_oxCH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 8  CH4_logn1 ~ CO2_soilC_mg_g_d + CH4_oxCH4_ox <~ 1*Bulk_dens + N
# 9  CH4_logn1 ~ CH4_gen + MOB_IIa\nCH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d\n
# 12 CH4_logn1 ~ CH4_gen + CH4_oxCH4_ox <~ 1*H2O_FPS + N
# 10 CH4_logn1  ~ CO2_soilC_mg_g_d + MOB_IIa
# 11 CH4_logn1  ~ CH4_ac + H2O_FPS

# %%
# Filter results by inspection

# %%
# drop bad tree composites
CH4_co2c_tree_c <-CH4_co2c_tree_c[as.character(CH4_co2c_tree_c$comp_failed) == 'character(0)',]
CH4_co2c_tree_c
#CH4_co2c_tree_c$comp_failed #== character(0)
# Out:
#   model_out        model        CH4_logn1
# 1 sem.ch4co2cD.91  ch4co2cD.91  CH4_logn1 ~ CH4_gen + CH4_ox
# 2 sem.ch4co2cD.104 ch4co2cD.104 CH4_logn1 ~ CH4_gen + CH4_ox
# 3 sem.ch4co2cD.105 ch4co2cD.105 CH4_logn1 ~ CH4_gen + CH4_ox
# 4 sem.ch4co2cD.64  ch4co2cD.64  CH4_logn1 ~ CH4_gen + CH4_ox
# 5 sem.ch4co2cD.67  ch4co2cD.67  CH4_logn1 ~ CH4_gen + CH4_ox
#   CH4_gen
# 1 CH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d
# 2 CH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d + pH
# 3 CH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d
# 4 CH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d
# 5 CH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d
#   CH4_ox                              comp_failed
# 1 CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 2 CH4_ox <~ 1*Bulk_dens + N
# 3 CH4_ox <~ 1*Bulk_dens + N + AOB
# 4 CH4_ox <~ 1*Bulk_dens + N
# 5 CH4_ox <~ 1*MOB_IIa + Bulk_dens
#   formula
# 1 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 2 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d + pH\nCH4_ox <~ 1*Bulk_dens + N
# 3 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d\nCH4_ox <~ 1*Bulk_dens + N + AOB
# 4 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d\nCH4_ox <~ 1*Bulk_dens + N
# 5 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_soilC_mg_g_d\nCH4_ox <~ 1*MOB_IIa + Bulk_dens

# %%
#CH4_co2c_tree_r <- run_sem_model_summary(CH4_co2c_tree_s2, Guild_CH4_dS, sort_by = 'pvalue', sort_cutoff = 0.01)

# %%
#CH4_co2c_tree_r

# %% [raw]
# # run composite models
# CH4_co2c_tree_r <- suppressWarnings(run_compare_sem_models(CH4_co2c_tree_c, Guild_CH4_dS,
#                                             estimator = "mlm", keep_mod_descr = c("model_out","model")))

# %% [raw]
# CH4_co2c_tree_r

# %% [raw]
# # show composite models
# CH4_mod_fch4.2_r

# %% [raw]
# # Get summary table and sort by p-value
# CH4_co2c_tree_s <- clean_SEM_model_table_for_output(CH4_co2c_tree_s2, CH4_co2c_tree_r,
#                                  drop_cols = c("model_out", "formula"), merge_col = c("model"))
#
# head(CH4_co2c_tree_s[order(-CH4_co2c_tree_s$pvalue),])

# %%
#tree_base

# %% [markdown]
# #### iii) MOB models

# %%
# newer workflow
d_mob2af <- get_sem_models_add_prefix(MOBIIa_delt_fAOANOB_sem, models = "filt_models", prefix = "mob2af.")
d_mob2afa <- get_sem_models_add_prefix(MOBIIa_delt_fAOANOB_sem, models = "sem_models", prefix = "mob2afa.",
                                     filter = 'R2', cutoff = 0.3)

d_mob2ngt <- get_sem_models_add_prefix(MOBIIa_delt_ngt_sem, models = "filt_models", prefix = "mob2ngt.")
d_mob2ngta <- get_sem_models_add_prefix(MOBIIa_delt_ngt_sem, models = "sem_models", prefix = "mob2ngta.",
                                     filter = 'R2', cutoff = 0.3)

# assign to branch and get y-var
branch_1 <- d_mob2af#a
#branch_1 <- d_mob2ngta
branch_1 <- rename_formula_col_as_yvar(branch_1)

# %%
#branch_1 <- branch_1[branch_1$R2 > 0.6,]
branch_1 <- branch_1[order(-branch_1$R2),]

# %%
branch_1
# Out:
#   model     aic     bic     npar R2
# 8 mob2af.20 821.251 866.913 21   0.745
# 6 mob2af.18 737.215 769.831 15   0.718
# 5 mob2af.14 722.787 768.449 21   0.718
# 7 mob2af.10 672.856 705.472 15   0.684
# 1 mob2af.8  607.334 629.078 10   0.659
# 4 mob2af.7  596.765 629.380 15   0.658
# 3 mob2af.4  575.509 597.253 10   0.631
# 2 mob2af.2  542.689 564.433 10   0.616
#   MOB_IIa                                        all_sig n_pred aic_glm
# 8 MOB_IIa  ~ C + Salinity.x + AOA + NOB + SO4    1       5      108.6987
# 6 MOB_IIa  ~ Salinity.x + H2O_FPS + AOA + NOB    1       4      113.1565
# 5 MOB_IIa  ~ Salinity.x + NO3_N + AOA + NOB + Cl 1       5      115.1041
# 7 MOB_IIa  ~ Salinity.x + Bulk_dens + AOA + NOB  1       4      120.6542
# 1 MOB_IIa  ~ H2O_FPS + AOA + NOB                 1       3      123.5197
# 4 MOB_IIa  ~ Salinity.x + AOA + NOB + Cl         1       4      125.6246
# 3 MOB_IIa  ~ Salinity.x + AOA + NOB              1       3      128.7276
# 2 MOB_IIa  ~ Bulk_dens + AOA + NOB               1       3      131.1573
#   bic_glm  aicc_glm resid vip_indx
# 8 123.9194 110.6636 0.017 1
# 6 126.2028 114.6048 0.028 3
# 5 130.3248 117.0690 0.034 4
# 7 133.7006 122.1025 0.022 2
# 1 134.3916 124.5367 0.027 8
# 4 138.6709 127.0729 0.030 5
# 3 139.5995 129.7445 0.013 6
# 2 142.0292 132.1742 0.013 7

# %% [markdown]
# #### iv) CH4 ac models

# %%
d_ch4ac.2 <- get_sem_models_add_prefix(CH4ac_delta.2_sem, prefix = "dac2.")
d_ch4ac.2a <- get_sem_models_add_prefix(CH4ac_delta.2_sem, models = "sem_models", prefix = "dac2.",
                                     filter = 'R2', cutoff = 0.5)

d_ch4ac.3 <- get_sem_models_add_prefix(CH4ac_delta.3_sem, prefix = "dac3.")
d_ch4ac.3a <- get_sem_models_add_prefix(CH4ac_delta.3_sem, models = "sem_models", prefix = "dac3a.",
                                     filter = 'R2', cutoff = 0.5)
d_ch4ac.4 <- get_sem_models_add_prefix(CH4ac_delta.4_sem, prefix = "dac4.")
d_ch4ac.4a <- get_sem_models_add_prefix(CH4ac_delta.4_sem, models = "sem_models", prefix = "dac4a.",
                                     filter = 'R2', cutoff = 0.3)

d_ch4ac.4f <- get_sem_models_add_prefix(CH4ac_delta_f_sem, prefix = "dac4f.")
d_ch4ac.4fa <- get_sem_models_add_prefix(CH4ac_delta_f_sem, models = "sem_models", prefix = "dac4a.",
                                     filter = 'R2', cutoff = 0.3)

# assign to branch and get y-var
branch_2 <- d_ch4ac.2#a
branch_2 <- rename_formula_col_as_yvar(branch_2)

# %%
#branch_2 <- branch_2[branch_2$R2 > 0.65,]

# %%
branch_2
# Out:
#    model   aic     bic     npar R2
# 12 dac2.54 886.403 932.065 21   0.717
# 11 dac2.60 903.421 949.084 21   0.724
# 10 dac2.38 751.242 783.858 15   0.685
# 9  dac2.16 591.275 613.019 10   0.643
# 8  dac2.58 898.927 944.589 21   0.729
# 7  dac2.36 741.466 774.082 15   0.678
# 6  dac2.39 752.396 785.011 15   0.679
# 5  dac2.17 591.758 613.502 10   0.640
# 4  dac2.4  450.079 463.125  6   0.548
# 3  dac2.24 649.838 671.582 10   0.667
# 2  dac2.6  487.834 500.881  6   0.515
# 1  dac2.7  488.590 501.636  6   0.525
#    CH4_ac                                              all_sig n_pred aic_glm
# 12 CH4_ac  ~ C + Bulk_dens + Cl + pH + H2O_FPS         1       5      115.3322
# 11 CH4_ac  ~ C + Bulk_dens + Cl + pH + SRB_syn         1       5      113.6670
# 10 CH4_ac  ~ C + Bulk_dens + Cl + SRB_syn              1       4      120.4281
# 9  CH4_ac  ~ C + Bulk_dens + Cl                        1       3      126.4589
# 8  CH4_ac  ~ C + Bulk_dens + pH + SRB_syn + Salinity.x 1       5      112.4733
# 7  CH4_ac  ~ C + Bulk_dens + pH + Salinity.x           1       4      121.8312
# 6  CH4_ac  ~ C + Bulk_dens + SRB_syn + Salinity.x      1       4      121.6689
# 5  CH4_ac  ~ C + Bulk_dens + Salinity.x                1       3      127.1304
# 4  CH4_ac  ~ C + Bulk_dens                             1       2      139.9103
# 3  CH4_ac  ~ C + Cl + H2O_FPS                          1       3      121.9577
# 2  CH4_ac  ~ C + Cl                                    1       2      144.3846
# 1  CH4_ac  ~ C + Salinity.x                            1       2      143.1092
#    bic_glm  aicc_glm resid vip_indx
# 12 130.5529 117.2971 0.039  1
# 11 128.8877 115.6319 0.033  2
# 10 133.4745 121.8764 0.114  3
# 9  137.3309 127.4759 0.198  4
# 8  127.6941 114.4383 0.041  5
# 7  134.8775 123.2795 0.114  6
# 6  134.7152 123.1172 0.107  7
# 5  138.0024 128.1474 0.194  8
# 4  148.6079 140.5770 0.214  9
# 3  132.8296 122.9746 0.176 10
# 2  153.0822 145.0513 0.151 11
# 1  151.8068 143.7759 0.161 12

# %% [markdown]
# ### b) run models

# %% [markdown]
# #### i) combine branches

# %%
# tree_base <- CH4_fg_tree_s
tree_base <- CH4_da_tree_s
# tree_base <- CH4_co2c_tree_s2

# %%
# make list of branches
#head(branch_1)
# branchz <- list(branch_1)
branchz2 <- list(branch_1, branch_2)

# %%
# combine branches, check n models-- note 720 models = 118 GB peak ram w delta DS
sem_formula_tree_d <-sem_tree_formula_build(tree_base, branchz2)
dim(sem_formula_tree_d)
head(sem_formula_tree_d)
# Out:
# [1] "480 sem models"
# [1] 480   8
#   model_out                     model
# 1 sem.dch4a.107_mob2af.8_dac2.7 dch4a.107_mob2af.8_dac2.7
# 2 sem.dch4a.69_mob2af.8_dac2.7  dch4a.69_mob2af.8_dac2.7
# 3 sem.dch4a.112_mob2af.8_dac2.7 dch4a.112_mob2af.8_dac2.7
# 4 sem.dch4a.109_mob2af.8_dac2.7 dch4a.109_mob2af.8_dac2.7
# 5 sem.dch4a.67_mob2af.8_dac2.7  dch4a.67_mob2af.8_dac2.7
# 6 sem.dch4a.107_mob2af.2_dac2.7 dch4a.107_mob2af.2_dac2.7
#   CH4_logn1                    CH4_gen
# 1 CH4_logn1 ~ CH4_gen + CH4_ox CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 2 CH4_logn1 ~ CH4_gen + CH4_ox CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 3 CH4_logn1 ~ CH4_gen + CH4_ox CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4
# 4 CH4_logn1 ~ CH4_gen + CH4_ox CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 5 CH4_logn1 ~ CH4_gen + CH4_ox CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 6 CH4_logn1 ~ CH4_gen + CH4_ox CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
#   CH4_ox                              MOB_IIa..
# 1 CH4_ox <~ 1*MOB_IIa + Bulk_dens + N MOB_IIa  ~ H2O_FPS + AOA + NOB
# 2 CH4_ox <~ 1*MOB_IIa + Bulk_dens     MOB_IIa  ~ H2O_FPS + AOA + NOB
# 3 CH4_ox <~ 1*Bulk_dens + N           MOB_IIa  ~ H2O_FPS + AOA + NOB
# 4 CH4_ox <~ 1*Bulk_dens + N + AOB     MOB_IIa  ~ H2O_FPS + AOA + NOB
# 5 CH4_ox <~ 1*Bulk_dens + N           MOB_IIa  ~ H2O_FPS + AOA + NOB
# 6 CH4_ox <~ 1*MOB_IIa + Bulk_dens + N MOB_IIa  ~ Bulk_dens + AOA + NOB
#   CH4_ac..
# 1 CH4_ac  ~ C + Salinity.x
# 2 CH4_ac  ~ C + Salinity.x
# 3 CH4_ac  ~ C + Salinity.x
# 4 CH4_ac  ~ C + Salinity.x
# 5 CH4_ac  ~ C + Salinity.x
# 6 CH4_ac  ~ C + Salinity.x
#   formula
# 1 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nMOB_IIa  ~ H2O_FPS + AOA + NOB\nCH4_ac  ~ C + Salinity.x
# 2 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nMOB_IIa  ~ H2O_FPS + AOA + NOB\nCH4_ac  ~ C + Salinity.x
# 3 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ H2O_FPS + AOA + NOB\nCH4_ac  ~ C + Salinity.x
# 4 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N + AOB\nMOB_IIa  ~ H2O_FPS + AOA + NOB\nCH4_ac  ~ C + Salinity.x
# 5 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ H2O_FPS + AOA + NOB\nCH4_ac  ~ C + Salinity.x
# 6 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nMOB_IIa  ~ Bulk_dens + AOA + NOB\nCH4_ac  ~ C + Salinity.x

# %% [markdown]
# #### ii) run models

# %%
# run simple delta models (4 min for 720? -- smaller data set) -- use SCALED dataset!! fails otherwise (& slower)!
sem_run_test_d <- run_sem_model_summary(sem_formula_tree_d, Guild_CH4_dS, sort_by = 'pvalue', sort_cutoff = 0.001) # pass parallel!!

# %%
sem_run_test_d
# dim(sem_run_test_d)
# head(sem_run_test_d)
# Out:
#     model                       pvalue chisq df npar aic    bic    gfi   cfi
# 149 dch4a.109_mob2af.20_dac2.38 0.007  40.4  21 84   1513.8 1696.4 0.929 0.934
# 245 dch4a.112_mob2af.20_dac2.38 0.005  37.0  18 73   1370.4 1529.1 0.931 0.936
# 147 dch4a.109_mob2af.20_dac2.24 0.004  44.0  22 83   1442.5 1623.0 0.922 0.926
# 243 dch4a.112_mob2af.20_dac2.24 0.003  40.9  19 72   1306.1 1462.7 0.921 0.926
# 246 dch4a.112_mob2af.20_dac2.39 0.003  34.9  15 63   1355.7 1492.7 0.929 0.933
# 145 dch4a.109_mob2af.20_dac2.16 0.002  41.9  19 72   1356.7 1513.2 0.920 0.922
# 150 dch4a.109_mob2af.20_dac2.39 0.002  40.4  18 73   1509.8 1668.5 0.924 0.925
# 17  dch4a.107_mob2af.14_dac2.38 0.001  44.5  19 72   1321.3 1477.9 0.921 0.912
# 18  dch4a.107_mob2af.14_dac2.39 0.001  45.8  19 72   1322.5 1479.1 0.918 0.908
# 27  dch4a.107_mob2af.18_dac2.24 0.001  42.2  18 60   1181.6 1312.0 0.917 0.916
# 29  dch4a.107_mob2af.18_dac2.38 0.001  44.4  20 71   1338.9 1493.3 0.921 0.916
# 30  dch4a.107_mob2af.18_dac2.39 0.001  42.8  17 61   1329.4 1462.1 0.918 0.911
# 51  dch4a.107_mob2af.20_dac2.24 0.001  47.0  20 71   1310.3 1464.7 0.911 0.909
# 53  dch4a.107_mob2af.20_dac2.38 0.001  43.1  19 72   1374.5 1531.1 0.919 0.919
# 54  dch4a.107_mob2af.20_dac2.39 0.001  41.1  16 62   1359.8 1494.6 0.917 0.915
# 91  dch4a.107_mob2af.8_dac2.4   0.001  37.4  14 41   1078.4 1167.6 0.916 0.909
# 113 dch4a.109_mob2af.14_dac2.38 0.001  45.6  21 84   1477.2 1659.8 0.924 0.917
# 114 dch4a.109_mob2af.14_dac2.39 0.001  46.9  21 84   1478.4 1661.0 0.922 0.912
# 123 dch4a.109_mob2af.18_dac2.24 0.001  47.0  20 71   1341.7 1496.1 0.914 0.909
# 125 dch4a.109_mob2af.18_dac2.38 0.001  49.4  22 83   1500.0 1680.5 0.918 0.908
# 146 dch4a.109_mob2af.20_dac2.17 0.001  41.2  16 62   1354.0 1488.8 0.916 0.914
# 155 dch4a.109_mob2af.20_dac2.60 0.001  51.2  23 97   1635.0 1845.9 0.918 0.910
# 187 dch4a.109_mob2af.8_dac2.4   0.001  38.1  16 50   1238.7 1347.5 0.922 0.916
# 209 dch4a.112_mob2af.14_dac2.38 0.001  47.4  21 84   1456.4 1639.1 0.922 0.911
# 210 dch4a.112_mob2af.14_dac2.39 0.001  48.7  21 84   1457.7 1640.3 0.919 0.907
# 235 dch4a.112_mob2af.2_dac2.4   0.001  35.1  13 42   1122.3 1213.6 0.923 0.914
# 241 dch4a.112_mob2af.20_dac2.16 0.001  38.9  16 62   1214.3 1349.1 0.921 0.922
# 242 dch4a.112_mob2af.20_dac2.17 0.001  36.4  13 53   1201.0 1316.3 0.919 0.920
# 341 dch4a.67_mob2af.20_dac2.38  0.001  45.3  19 72   1376.7 1533.3 0.915 0.911
# 475 dch4a.69_mob2af.8_dac2.4    0.001  34.6  12 33   1130.6 1202.3 0.912 0.910
#     rni   rmsea srmr  CH4_logn1.x MOB_IIa CH4_ac CH4_logn1.y
# 149 0.934 0.119 0.030 0.847       0.740   0.685  CH4_gen + CH4_ox
# 245 0.936 0.127 0.030 0.851       0.742   0.685  CH4_gen + CH4_ox
# 147 0.926 0.124 0.031 0.853       0.740   0.667  CH4_gen + CH4_ox
# 243 0.926 0.133 0.033 0.856       0.742   0.667  CH4_gen + CH4_ox
# 246 0.933 0.143 0.030 0.851       0.742   0.679  CH4_gen + CH4_ox
# 145 0.922 0.136 0.031 0.849       0.740   0.643  CH4_gen + CH4_ox
# 150 0.925 0.138 0.031 0.848       0.740   0.679  CH4_gen + CH4_ox
# 17  0.912 0.144 0.037 0.837       0.718   0.685  CH4_gen + CH4_ox
# 18  0.908 0.147 0.036 0.837       0.718   0.679  CH4_gen + CH4_ox
# 27  0.916 0.144 0.036 0.845       0.718   0.667  CH4_gen + CH4_ox
# 29  0.916 0.137 0.037 0.838       0.718   0.685  CH4_gen + CH4_ox
# 30  0.911 0.153 0.037 0.839       0.718   0.679  CH4_gen + CH4_ox
# 51  0.909 0.144 0.031 0.845       0.745   0.667  CH4_gen + CH4_ox
# 53  0.919 0.140 0.029 0.840       0.745   0.685  CH4_gen + CH4_ox
# 54  0.915 0.155 0.029 0.840       0.745   0.679  CH4_gen + CH4_ox
# 91  0.909 0.160 0.052 0.839       0.659   0.548  CH4_gen + CH4_ox
# 113 0.917 0.134 0.036 0.845       0.715   0.685  CH4_gen + CH4_ox
# 114 0.912 0.138 0.036 0.845       0.715   0.679  CH4_gen + CH4_ox
# 123 0.909 0.144 0.034 0.854       0.715   0.667  CH4_gen + CH4_ox
# 125 0.908 0.138 0.035 0.848       0.715   0.685  CH4_gen + CH4_ox
# 146 0.914 0.156 0.032 0.850       0.740   0.640  CH4_gen + CH4_ox
# 155 0.910 0.137 0.026 0.851       0.740   0.724  CH4_gen + CH4_ox
# 187 0.916 0.146 0.048 0.847       0.658   0.548  CH4_gen + CH4_ox
# 209 0.911 0.139 0.037 0.848       0.716   0.685  CH4_gen + CH4_ox
# 210 0.907 0.142 0.036 0.848       0.716   0.679  CH4_gen + CH4_ox
# 235 0.914 0.162 0.061 0.846       0.617   0.548  CH4_gen + CH4_ox
# 241 0.922 0.148 0.033 0.854       0.742   0.643  CH4_gen + CH4_ox
# 242 0.920 0.166 0.033 0.853       0.742   0.640  CH4_gen + CH4_ox
# 341 0.911 0.146 0.036 0.826       0.737   0.685  CH4_gen + CH4_ox
# 475 0.910 0.170 0.057 0.818       0.659   0.548  CH4_gen + CH4_ox
#     CH4_gen                      CH4_ox
# 149 1*CH4_ac + CO2_mg_m2_h       1*Bulk_dens + N + AOB
# 245 1*CH4_ac + CO2_mg_m2_h + SO4 1*Bulk_dens + N
# 147 1*CH4_ac + CO2_mg_m2_h       1*Bulk_dens + N + AOB
# 243 1*CH4_ac + CO2_mg_m2_h + SO4 1*Bulk_dens + N
# 246 1*CH4_ac + CO2_mg_m2_h + SO4 1*Bulk_dens + N
# 145 1*CH4_ac + CO2_mg_m2_h       1*Bulk_dens + N + AOB
# 150 1*CH4_ac + CO2_mg_m2_h       1*Bulk_dens + N + AOB
# 17  1*CH4_ac + CO2_mg_m2_h       1*MOB_IIa + Bulk_dens + N
# 18  1*CH4_ac + CO2_mg_m2_h       1*MOB_IIa + Bulk_dens + N
# 27  1*CH4_ac + CO2_mg_m2_h       1*MOB_IIa + Bulk_dens + N
# 29  1*CH4_ac + CO2_mg_m2_h       1*MOB_IIa + Bulk_dens + N
# 30  1*CH4_ac + CO2_mg_m2_h       1*MOB_IIa + Bulk_dens + N
# 51  1*CH4_ac + CO2_mg_m2_h       1*MOB_IIa + Bulk_dens + N
# 53  1*CH4_ac + CO2_mg_m2_h       1*MOB_IIa + Bulk_dens + N
# 54  1*CH4_ac + CO2_mg_m2_h       1*MOB_IIa + Bulk_dens + N
# 91  1*CH4_ac + CO2_mg_m2_h       1*MOB_IIa + Bulk_dens + N
# 113 1*CH4_ac + CO2_mg_m2_h       1*Bulk_dens + N + AOB
# 114 1*CH4_ac + CO2_mg_m2_h       1*Bulk_dens + N + AOB
# 123 1*CH4_ac + CO2_mg_m2_h       1*Bulk_dens + N + AOB
# 125 1*CH4_ac + CO2_mg_m2_h       1*Bulk_dens + N + AOB
# 146 1*CH4_ac + CO2_mg_m2_h       1*Bulk_dens + N + AOB
# 155 1*CH4_ac + CO2_mg_m2_h       1*Bulk_dens + N + AOB
# 187 1*CH4_ac + CO2_mg_m2_h       1*Bulk_dens + N + AOB
# 209 1*CH4_ac + CO2_mg_m2_h + SO4 1*Bulk_dens + N
# 210 1*CH4_ac + CO2_mg_m2_h + SO4 1*Bulk_dens + N
# 235 1*CH4_ac + CO2_mg_m2_h + SO4 1*Bulk_dens + N
# 241 1*CH4_ac + CO2_mg_m2_h + SO4 1*Bulk_dens + N
# 242 1*CH4_ac + CO2_mg_m2_h + SO4 1*Bulk_dens + N
# 341 1*CH4_ac + CO2_mg_m2_h       1*Bulk_dens + N
# 475 1*CH4_ac + CO2_mg_m2_h       1*MOB_IIa + Bulk_dens
#     MOB_IIa..                           CH4_ac..
# 149 C + Salinity.x + AOA + NOB + SO4    C + Bulk_dens + Cl + SRB_syn
# 245 C + Salinity.x + AOA + NOB + SO4    C + Bulk_dens + Cl + SRB_syn
# 147 C + Salinity.x + AOA + NOB + SO4    C + Cl + H2O_FPS
# 243 C + Salinity.x + AOA + NOB + SO4    C + Cl + H2O_FPS
# 246 C + Salinity.x + AOA + NOB + SO4    C + Bulk_dens + SRB_syn + Salinity.x
# 145 C + Salinity.x + AOA + NOB + SO4    C + Bulk_dens + Cl
# 150 C + Salinity.x + AOA + NOB + SO4    C + Bulk_dens + SRB_syn + Salinity.x
# 17  Salinity.x + NO3_N + AOA + NOB + Cl C + Bulk_dens + Cl + SRB_syn
# 18  Salinity.x + NO3_N + AOA + NOB + Cl C + Bulk_dens + SRB_syn + Salinity.x
# 27  Salinity.x + H2O_FPS + AOA + NOB    C + Cl + H2O_FPS
# 29  Salinity.x + H2O_FPS + AOA + NOB    C + Bulk_dens + Cl + SRB_syn
# 30  Salinity.x + H2O_FPS + AOA + NOB    C + Bulk_dens + SRB_syn + Salinity.x
# 51  C + Salinity.x + AOA + NOB + SO4    C + Cl + H2O_FPS
# 53  C + Salinity.x + AOA + NOB + SO4    C + Bulk_dens + Cl + SRB_syn
# 54  C + Salinity.x + AOA + NOB + SO4    C + Bulk_dens + SRB_syn + Salinity.x
# 91  H2O_FPS + AOA + NOB                 C + Bulk_dens
# 113 Salinity.x + NO3_N + AOA + NOB + Cl C + Bulk_dens + Cl + SRB_syn
# 114 Salinity.x + NO3_N + AOA + NOB + Cl C + Bulk_dens + SRB_syn + Salinity.x
# 123 Salinity.x + H2O_FPS + AOA + NOB    C + Cl + H2O_FPS
# 125 Salinity.x + H2O_FPS + AOA + NOB    C + Bulk_dens + Cl + SRB_syn
# 146 C + Salinity.x + AOA + NOB + SO4    C + Bulk_dens + Salinity.x
# 155 C + Salinity.x + AOA + NOB + SO4    C + Bulk_dens + Cl + pH + SRB_syn
# 187 H2O_FPS + AOA + NOB                 C + Bulk_dens
# 209 Salinity.x + NO3_N + AOA + NOB + Cl C + Bulk_dens + Cl + SRB_syn
# 210 Salinity.x + NO3_N + AOA + NOB + Cl C + Bulk_dens + SRB_syn + Salinity.x
# 235 Bulk_dens + AOA + NOB               C + Bulk_dens
# 241 C + Salinity.x + AOA + NOB + SO4    C + Bulk_dens + Cl
# 242 C + Salinity.x + AOA + NOB + SO4    C + Bulk_dens + Salinity.x
# 341 C + Salinity.x + AOA + NOB + SO4    C + Bulk_dens + Cl + SRB_syn
# 475 H2O_FPS + AOA + NOB                 C + Bulk_dens

# %%
# filter results before printing
# sem_run_test_d <- sem_run_test_d[sem_run_test_d$pvalue > 0.05,]

# %%
# write.table(sem_run_test_d, "auto_tables/delta_CO2C2_mobafa_ac.4a_noClP_1140.txt", sep='\t', row.names=FALSE)
# write.table(sem_run_test_d, "auto_tables/delta_CH7f_mob_2afaf_ac4af_noClP_1330.txt", sep='\t', row.names=FALSE)

#write.table(sem_run_test, "auto_tables/delta_CO2C_mobaf_ac.2_noSal_675.txt", sep='\t', row.names=FALSE)
# write.table(sem_run_test_d, "auto_tables/delta_CH7f_mobngALL_ac2a_noSal_1953.txt", sep='\t', row.names=FALSE)

# %% [markdown]
# ## 5) Single sided branched models CH4 + MOB; CH4 + CH4_ac

# %% [markdown]
# ## c) single sided CH4_MOB trees

# %%
# tree_base <- CH4_fg_tree_s
tree_base <- CH4_da_tree_s
#tree_base <- CH4_fg_tree_s
#tree_base <- CH4_co2c_tree_s2

# %%
# assign to branch and get y-var 
branch_1 <- d_mob2afa                                    # 2af, 2afa
#branch_1 <- d_mob2ngta                                 # 2ngt, 2ngta  
branch_1 <- rename_formula_col_as_yvar(branch_1)

# %%
branchz <- list(branch_1)

# %%
# combine branches, check n models-- note 720 models = 118 GB peak ram w delta DS
sem_formula_tree_d <-sem_tree_formula_build(tree_base, branchz)
sem_formula_tree_d
# Out:
# [1] "100 sem models"
#     model_out                model                CH4_logn1
# 1   sem.dch4a.107_mob2afa.1  dch4a.107_mob2afa.1  CH4_logn1 ~ CH4_gen + CH4_ox
# 2   sem.dch4a.69_mob2afa.1   dch4a.69_mob2afa.1   CH4_logn1 ~ CH4_gen + CH4_ox
# 3   sem.dch4a.112_mob2afa.1  dch4a.112_mob2afa.1  CH4_logn1 ~ CH4_gen + CH4_ox
# 4   sem.dch4a.109_mob2afa.1  dch4a.109_mob2afa.1  CH4_logn1 ~ CH4_gen + CH4_ox
# 5   sem.dch4a.67_mob2afa.1   dch4a.67_mob2afa.1   CH4_logn1 ~ CH4_gen + CH4_ox
# 6   sem.dch4a.107_mob2afa.5  dch4a.107_mob2afa.5  CH4_logn1 ~ CH4_gen + CH4_ox
# 7   sem.dch4a.69_mob2afa.5   dch4a.69_mob2afa.5   CH4_logn1 ~ CH4_gen + CH4_ox
# 8   sem.dch4a.112_mob2afa.5  dch4a.112_mob2afa.5  CH4_logn1 ~ CH4_gen + CH4_ox
# 9   sem.dch4a.109_mob2afa.5  dch4a.109_mob2afa.5  CH4_logn1 ~ CH4_gen + CH4_ox
# 10  sem.dch4a.67_mob2afa.5   dch4a.67_mob2afa.5   CH4_logn1 ~ CH4_gen + CH4_ox
# 11  sem.dch4a.107_mob2afa.15 dch4a.107_mob2afa.15 CH4_logn1 ~ CH4_gen + CH4_ox
# 12  sem.dch4a.69_mob2afa.15  dch4a.69_mob2afa.15  CH4_logn1 ~ CH4_gen + CH4_ox
# 13  sem.dch4a.112_mob2afa.15 dch4a.112_mob2afa.15 CH4_logn1 ~ CH4_gen + CH4_ox
# 14  sem.dch4a.109_mob2afa.15 dch4a.109_mob2afa.15 CH4_logn1 ~ CH4_gen + CH4_ox
# 15  sem.dch4a.67_mob2afa.15  dch4a.67_mob2afa.15  CH4_logn1 ~ CH4_gen + CH4_ox
# 16  sem.dch4a.107_mob2afa.6  dch4a.107_mob2afa.6  CH4_logn1 ~ CH4_gen + CH4_ox
# 17  sem.dch4a.69_mob2afa.6   dch4a.69_mob2afa.6   CH4_logn1 ~ CH4_gen + CH4_ox
# 18  sem.dch4a.112_mob2afa.6  dch4a.112_mob2afa.6  CH4_logn1 ~ CH4_gen + CH4_ox
# 19  sem.dch4a.109_mob2afa.6  dch4a.109_mob2afa.6  CH4_logn1 ~ CH4_gen + CH4_ox
# 20  sem.dch4a.67_mob2afa.6   dch4a.67_mob2afa.6   CH4_logn1 ~ CH4_gen + CH4_ox
# 21  sem.dch4a.107_mob2afa.3  dch4a.107_mob2afa.3  CH4_logn1 ~ CH4_gen + CH4_ox
# 22  sem.dch4a.69_mob2afa.3   dch4a.69_mob2afa.3   CH4_logn1 ~ CH4_gen + CH4_ox
# 23  sem.dch4a.112_mob2afa.3  dch4a.112_mob2afa.3  CH4_logn1 ~ CH4_gen + CH4_ox
# 24  sem.dch4a.109_mob2afa.3  dch4a.109_mob2afa.3  CH4_logn1 ~ CH4_gen + CH4_ox
# 25  sem.dch4a.67_mob2afa.3   dch4a.67_mob2afa.3   CH4_logn1 ~ CH4_gen + CH4_ox
# 26  sem.dch4a.107_mob2afa.13 dch4a.107_mob2afa.13 CH4_logn1 ~ CH4_gen + CH4_ox
# 27  sem.dch4a.69_mob2afa.13  dch4a.69_mob2afa.13  CH4_logn1 ~ CH4_gen + CH4_ox
# 28  sem.dch4a.112_mob2afa.13 dch4a.112_mob2afa.13 CH4_logn1 ~ CH4_gen + CH4_ox
# 29  sem.dch4a.109_mob2afa.13 dch4a.109_mob2afa.13 CH4_logn1 ~ CH4_gen + CH4_ox
# 30  sem.dch4a.67_mob2afa.13  dch4a.67_mob2afa.13  CH4_logn1 ~ CH4_gen + CH4_ox
# ⋮   ⋮                        ⋮                    ⋮
# 71  sem.dch4a.107_mob2afa.14 dch4a.107_mob2afa.14 CH4_logn1 ~ CH4_gen + CH4_ox
# 72  sem.dch4a.69_mob2afa.14  dch4a.69_mob2afa.14  CH4_logn1 ~ CH4_gen + CH4_ox
# 73  sem.dch4a.112_mob2afa.14 dch4a.112_mob2afa.14 CH4_logn1 ~ CH4_gen + CH4_ox
# 74  sem.dch4a.109_mob2afa.14 dch4a.109_mob2afa.14 CH4_logn1 ~ CH4_gen + CH4_ox
# 75  sem.dch4a.67_mob2afa.14  dch4a.67_mob2afa.14  CH4_logn1 ~ CH4_gen + CH4_ox
# 76  sem.dch4a.107_mob2afa.18 dch4a.107_mob2afa.18 CH4_logn1 ~ CH4_gen + CH4_ox
# 77  sem.dch4a.69_mob2afa.18  dch4a.69_mob2afa.18  CH4_logn1 ~ CH4_gen + CH4_ox
# 78  sem.dch4a.112_mob2afa.18 dch4a.112_mob2afa.18 CH4_logn1 ~ CH4_gen + CH4_ox
# 79  sem.dch4a.109_mob2afa.18 dch4a.109_mob2afa.18 CH4_logn1 ~ CH4_gen + CH4_ox
# 80  sem.dch4a.67_mob2afa.18  dch4a.67_mob2afa.18  CH4_logn1 ~ CH4_gen + CH4_ox
# 81  sem.dch4a.107_mob2afa.10 dch4a.107_mob2afa.10 CH4_logn1 ~ CH4_gen + CH4_ox
# 82  sem.dch4a.69_mob2afa.10  dch4a.69_mob2afa.10  CH4_logn1 ~ CH4_gen + CH4_ox
# 83  sem.dch4a.112_mob2afa.10 dch4a.112_mob2afa.10 CH4_logn1 ~ CH4_gen + CH4_ox
# 84  sem.dch4a.109_mob2afa.10 dch4a.109_mob2afa.10 CH4_logn1 ~ CH4_gen + CH4_ox
# 85  sem.dch4a.67_mob2afa.10  dch4a.67_mob2afa.10  CH4_logn1 ~ CH4_gen + CH4_ox
# 86  sem.dch4a.107_mob2afa.19 dch4a.107_mob2afa.19 CH4_logn1 ~ CH4_gen + CH4_ox
# 87  sem.dch4a.69_mob2afa.19  dch4a.69_mob2afa.19  CH4_logn1 ~ CH4_gen + CH4_ox
# 88  sem.dch4a.112_mob2afa.19 dch4a.112_mob2afa.19 CH4_logn1 ~ CH4_gen + CH4_ox
# 89  sem.dch4a.109_mob2afa.19 dch4a.109_mob2afa.19 CH4_logn1 ~ CH4_gen + CH4_ox
# 90  sem.dch4a.67_mob2afa.19  dch4a.67_mob2afa.19  CH4_logn1 ~ CH4_gen + CH4_ox
# 91  sem.dch4a.107_mob2afa.9  dch4a.107_mob2afa.9  CH4_logn1 ~ CH4_gen + CH4_ox
# 92  sem.dch4a.69_mob2afa.9   dch4a.69_mob2afa.9   CH4_logn1 ~ CH4_gen + CH4_ox
# 93  sem.dch4a.112_mob2afa.9  dch4a.112_mob2afa.9  CH4_logn1 ~ CH4_gen + CH4_ox
# 94  sem.dch4a.109_mob2afa.9  dch4a.109_mob2afa.9  CH4_logn1 ~ CH4_gen + CH4_ox
# 95  sem.dch4a.67_mob2afa.9   dch4a.67_mob2afa.9   CH4_logn1 ~ CH4_gen + CH4_ox
# 96  sem.dch4a.107_mob2afa.20 dch4a.107_mob2afa.20 CH4_logn1 ~ CH4_gen + CH4_ox
# 97  sem.dch4a.69_mob2afa.20  dch4a.69_mob2afa.20  CH4_logn1 ~ CH4_gen + CH4_ox
# 98  sem.dch4a.112_mob2afa.20 dch4a.112_mob2afa.20 CH4_logn1 ~ CH4_gen + CH4_ox
# 99  sem.dch4a.109_mob2afa.20 dch4a.109_mob2afa.20 CH4_logn1 ~ CH4_gen + CH4_ox
# 100 sem.dch4a.67_mob2afa.20  dch4a.67_mob2afa.20  CH4_logn1 ~ CH4_gen + CH4_ox
#     CH4_gen                                 CH4_ox
# 1   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 2   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 3   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4 CH4_ox <~ 1*Bulk_dens + N
# 4   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N + AOB
# 5   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N
# 6   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 7   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 8   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4 CH4_ox <~ 1*Bulk_dens + N
# 9   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N + AOB
# 10  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N
# 11  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 12  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 13  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4 CH4_ox <~ 1*Bulk_dens + N
# 14  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N + AOB
# 15  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N
# 16  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 17  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 18  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4 CH4_ox <~ 1*Bulk_dens + N
# 19  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N + AOB
# 20  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N
# 21  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 22  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 23  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4 CH4_ox <~ 1*Bulk_dens + N
# 24  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N + AOB
# 25  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N
# 26  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 27  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 28  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4 CH4_ox <~ 1*Bulk_dens + N
# 29  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N + AOB
# 30  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N
# ⋮   ⋮                                       ⋮
# 71  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 72  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 73  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4 CH4_ox <~ 1*Bulk_dens + N
# 74  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N + AOB
# 75  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N
# 76  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 77  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 78  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4 CH4_ox <~ 1*Bulk_dens + N
# 79  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N + AOB
# 80  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N
# 81  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 82  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 83  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4 CH4_ox <~ 1*Bulk_dens + N
# 84  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N + AOB
# 85  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N
# 86  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 87  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 88  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4 CH4_ox <~ 1*Bulk_dens + N
# 89  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N + AOB
# 90  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N
# 91  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 92  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 93  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4 CH4_ox <~ 1*Bulk_dens + N
# 94  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N + AOB
# 95  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N
# 96  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 97  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 98  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4 CH4_ox <~ 1*Bulk_dens + N
# 99  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N + AOB
# 100 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h       CH4_ox <~ 1*Bulk_dens + N
#     MOB_IIa..
# 1   MOB_IIa  ~ AOA + NOB
# 2   MOB_IIa  ~ AOA + NOB
# 3   MOB_IIa  ~ AOA + NOB
# 4   MOB_IIa  ~ AOA + NOB
# 5   MOB_IIa  ~ AOA + NOB
# 6   MOB_IIa  ~ AOA + NOB + Cl
# 7   MOB_IIa  ~ AOA + NOB + Cl
# 8   MOB_IIa  ~ AOA + NOB + Cl
# 9   MOB_IIa  ~ AOA + NOB + Cl
# 10  MOB_IIa  ~ AOA + NOB + Cl
# 11  MOB_IIa  ~ AOA + NOB + SO4 + Cl
# 12  MOB_IIa  ~ AOA + NOB + SO4 + Cl
# 13  MOB_IIa  ~ AOA + NOB + SO4 + Cl
# 14  MOB_IIa  ~ AOA + NOB + SO4 + Cl
# 15  MOB_IIa  ~ AOA + NOB + SO4 + Cl
# 16  MOB_IIa  ~ AOA + NH4_N + NOB
# 17  MOB_IIa  ~ AOA + NH4_N + NOB
# 18  MOB_IIa  ~ AOA + NH4_N + NOB
# 19  MOB_IIa  ~ AOA + NH4_N + NOB
# 20  MOB_IIa  ~ AOA + NH4_N + NOB
# 21  MOB_IIa  ~ NO3_N + AOA + NOB
# 22  MOB_IIa  ~ NO3_N + AOA + NOB
# 23  MOB_IIa  ~ NO3_N + AOA + NOB
# 24  MOB_IIa  ~ NO3_N + AOA + NOB
# 25  MOB_IIa  ~ NO3_N + AOA + NOB
# 26  MOB_IIa  ~ NO3_N + AOA + NOB + Cl
# 27  MOB_IIa  ~ NO3_N + AOA + NOB + Cl
# 28  MOB_IIa  ~ NO3_N + AOA + NOB + Cl
# 29  MOB_IIa  ~ NO3_N + AOA + NOB + Cl
# 30  MOB_IIa  ~ NO3_N + AOA + NOB + Cl
# ⋮   ⋮
# 71  MOB_IIa  ~ Salinity.x + NO3_N + AOA + NOB + Cl
# 72  MOB_IIa  ~ Salinity.x + NO3_N + AOA + NOB + Cl
# 73  MOB_IIa  ~ Salinity.x + NO3_N + AOA + NOB + Cl
# 74  MOB_IIa  ~ Salinity.x + NO3_N + AOA + NOB + Cl
# 75  MOB_IIa  ~ Salinity.x + NO3_N + AOA + NOB + Cl
# 76  MOB_IIa  ~ Salinity.x + H2O_FPS + AOA + NOB
# 77  MOB_IIa  ~ Salinity.x + H2O_FPS + AOA + NOB
# 78  MOB_IIa  ~ Salinity.x + H2O_FPS + AOA + NOB
# 79  MOB_IIa  ~ Salinity.x + H2O_FPS + AOA + NOB
# 80  MOB_IIa  ~ Salinity.x + H2O_FPS + AOA + NOB
# 81  MOB_IIa  ~ Salinity.x + Bulk_dens + AOA + NOB
# 82  MOB_IIa  ~ Salinity.x + Bulk_dens + AOA + NOB
# 83  MOB_IIa  ~ Salinity.x + Bulk_dens + AOA + NOB
# 84  MOB_IIa  ~ Salinity.x + Bulk_dens + AOA + NOB
# 85  MOB_IIa  ~ Salinity.x + Bulk_dens + AOA + NOB
# 86  MOB_IIa  ~ C + AOA + NOB + SO4 + Cl
# 87  MOB_IIa  ~ C + AOA + NOB + SO4 + Cl
# 88  MOB_IIa  ~ C + AOA + NOB + SO4 + Cl
# 89  MOB_IIa  ~ C + AOA + NOB + SO4 + Cl
# 90  MOB_IIa  ~ C + AOA + NOB + SO4 + Cl
# 91  MOB_IIa  ~ C + Bulk_dens + AOA + NOB
# 92  MOB_IIa  ~ C + Bulk_dens + AOA + NOB
# 93  MOB_IIa  ~ C + Bulk_dens + AOA + NOB
# 94  MOB_IIa  ~ C + Bulk_dens + AOA + NOB
# 95  MOB_IIa  ~ C + Bulk_dens + AOA + NOB
# 96  MOB_IIa  ~ C + Salinity.x + AOA + NOB + SO4
# 97  MOB_IIa  ~ C + Salinity.x + AOA + NOB + SO4
# 98  MOB_IIa  ~ C + Salinity.x + AOA + NOB + SO4
# 99  MOB_IIa  ~ C + Salinity.x + AOA + NOB + SO4
# 100 MOB_IIa  ~ C + Salinity.x + AOA + NOB + SO4
#     formula
# 1   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nMOB_IIa  ~ AOA + NOB
# 2   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nMOB_IIa  ~ AOA + NOB
# 3   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ AOA + NOB
# 4   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N + AOB\nMOB_IIa  ~ AOA + NOB
# 5   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ AOA + NOB
# 6   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nMOB_IIa  ~ AOA + NOB + Cl
# 7   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nMOB_IIa  ~ AOA + NOB + Cl
# 8   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ AOA + NOB + Cl
# 9   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N + AOB\nMOB_IIa  ~ AOA + NOB + Cl
# 10  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ AOA + NOB + Cl
# 11  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nMOB_IIa  ~ AOA + NOB + SO4 + Cl
# 12  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nMOB_IIa  ~ AOA + NOB + SO4 + Cl
# 13  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ AOA + NOB + SO4 + Cl
# 14  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N + AOB\nMOB_IIa  ~ AOA + NOB + SO4 + Cl
# 15  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ AOA + NOB + SO4 + Cl
# 16  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nMOB_IIa  ~ AOA + NH4_N + NOB
# 17  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nMOB_IIa  ~ AOA + NH4_N + NOB
# 18  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ AOA + NH4_N + NOB
# 19  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N + AOB\nMOB_IIa  ~ AOA + NH4_N + NOB
# 20  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ AOA + NH4_N + NOB
# 21  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nMOB_IIa  ~ NO3_N + AOA + NOB
# 22  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nMOB_IIa  ~ NO3_N + AOA + NOB
# 23  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ NO3_N + AOA + NOB
# 24  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N + AOB\nMOB_IIa  ~ NO3_N + AOA + NOB
# 25  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ NO3_N + AOA + NOB
# 26  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nMOB_IIa  ~ NO3_N + AOA + NOB + Cl
# 27  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nMOB_IIa  ~ NO3_N + AOA + NOB + Cl
# 28  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ NO3_N + AOA + NOB + Cl
# 29  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N + AOB\nMOB_IIa  ~ NO3_N + AOA + NOB + Cl
# 30  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ NO3_N + AOA + NOB + Cl
# ⋮   ⋮
# 71  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nMOB_IIa  ~ Salinity.x + NO3_N + AOA + NOB + Cl
# 72  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nMOB_IIa  ~ Salinity.x + NO3_N + AOA + NOB + Cl
# 73  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ Salinity.x + NO3_N + AOA + NOB + Cl
# 74  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N + AOB\nMOB_IIa  ~ Salinity.x + NO3_N + AOA + NOB + Cl
# 75  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ Salinity.x + NO3_N + AOA + NOB + Cl
# 76  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nMOB_IIa  ~ Salinity.x + H2O_FPS + AOA + NOB
# 77  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nMOB_IIa  ~ Salinity.x + H2O_FPS + AOA + NOB
# 78  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ Salinity.x + H2O_FPS + AOA + NOB
# 79  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N + AOB\nMOB_IIa  ~ Salinity.x + H2O_FPS + AOA + NOB
# 80  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ Salinity.x + H2O_FPS + AOA + NOB
# 81  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nMOB_IIa  ~ Salinity.x + Bulk_dens + AOA + NOB
# 82  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nMOB_IIa  ~ Salinity.x + Bulk_dens + AOA + NOB
# 83  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ Salinity.x + Bulk_dens + AOA + NOB
# 84  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N + AOB\nMOB_IIa  ~ Salinity.x + Bulk_dens + AOA + NOB
# 85  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ Salinity.x + Bulk_dens + AOA + NOB
# 86  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nMOB_IIa  ~ C + AOA + NOB + SO4 + Cl
# 87  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nMOB_IIa  ~ C + AOA + NOB + SO4 + Cl
# 88  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ C + AOA + NOB + SO4 + Cl
# 89  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N + AOB\nMOB_IIa  ~ C + AOA + NOB + SO4 + Cl
# 90  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ C + AOA + NOB + SO4 + Cl
# 91  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nMOB_IIa  ~ C + Bulk_dens + AOA + NOB
# 92  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nMOB_IIa  ~ C + Bulk_dens + AOA + NOB
# 93  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ C + Bulk_dens + AOA + NOB
# 94  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N + AOB\nMOB_IIa  ~ C + Bulk_dens + AOA + NOB
# 95  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ C + Bulk_dens + AOA + NOB
# 96  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nMOB_IIa  ~ C + Salinity.x + AOA + NOB + SO4
# 97  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nMOB_IIa  ~ C + Salinity.x + AOA + NOB + SO4
# 98  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ C + Salinity.x + AOA + NOB + SO4
# 99  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N + AOB\nMOB_IIa  ~ C + Salinity.x + AOA + NOB + SO4
# 100 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*Bulk_dens + N\nMOB_IIa  ~ C + Salinity.x + AOA + NOB + SO4

# %%
# run simple delta models (4 min for 720? -- smaller data set) -- use SCALED dataset!! fails otherwise (& slower)!
# sem_run_test_d_mob <-run_sem_model_summary(sem_formula_tree_d, Guild_CH4_dS, sort_by = 'pvalue', sort_cutoff = 0.001) # pass parallel!!

# %%
# sem_run_test_d_mob

# %%
# filter results before printing
# sem_run_test__mob <- sem_run_test__mob[sem_run_test_mob$pvalue > 0.05,]

# %%
# write.table(sem_run_test_d_mob, "auto_tables/MOB_delta_CH4f5_fga_noClP_60.txt", sep='\t', row.names=FALSE)

# %% [markdown]
# ## d) single sided CH4_ac trees

# %%
tree_base <- CH4_fg_tree_s
#tree_base <- CH4_da_tree_s

# %%
# assign to branch and get y-var
branch_2 <- d_ch4ac.4fa                               #2, 2a, 3, 3a, 4, 4a, 4f, 4fa
branch_2 <- rename_formula_col_as_yvar(branch_2)

# %%
branchz <- list(branch_2)

# %%
# combine branches, check n models-- note 720 models = 118 GB peak ram w delta DS
sem_formula_tree_d <-sem_tree_formula_build(tree_base, branchz)
sem_formula_tree_d
# Out:
# [1] "1022 sem models"
#      model_out              model              CH4_logn1
# 1    sem.ch4fg.7_dac4a.1    ch4fg.7_dac4a.1    CH4_logn1 ~ CH4_gen + CH4_ox
# 2    sem.ch4fg.9_dac4a.1    ch4fg.9_dac4a.1    CH4_logn1 ~ CH4_gen + CH4_ox
# 3    sem.ch4fg.8_dac4a.1    ch4fg.8_dac4a.1    CH4_logn1 ~ CH4_gen + CH4_ox
# 4    sem.ch4fg.6_dac4a.1    ch4fg.6_dac4a.1    CH4_logn1 ~ CH4_gen + CH4_ox
# 5    sem.ch4fg.3_dac4a.1    ch4fg.3_dac4a.1    CH4_logn1 ~ CH4_gen + CH4_ox
# 6    sem.ch4fg.10_dac4a.1   ch4fg.10_dac4a.1   CH4_logn1 ~ CH4_gen + CH4_ox
# 7    sem.ch4fg.5_dac4a.1    ch4fg.5_dac4a.1    CH4_logn1 ~ CH4_gen + CH4_ox
# 8    sem.ch4fg.7_dac4a.19   ch4fg.7_dac4a.19   CH4_logn1 ~ CH4_gen + CH4_ox
# 9    sem.ch4fg.9_dac4a.19   ch4fg.9_dac4a.19   CH4_logn1 ~ CH4_gen + CH4_ox
# 10   sem.ch4fg.8_dac4a.19   ch4fg.8_dac4a.19   CH4_logn1 ~ CH4_gen + CH4_ox
# 11   sem.ch4fg.6_dac4a.19   ch4fg.6_dac4a.19   CH4_logn1 ~ CH4_gen + CH4_ox
# 12   sem.ch4fg.3_dac4a.19   ch4fg.3_dac4a.19   CH4_logn1 ~ CH4_gen + CH4_ox
# 13   sem.ch4fg.10_dac4a.19  ch4fg.10_dac4a.19  CH4_logn1 ~ CH4_gen + CH4_ox
# 14   sem.ch4fg.5_dac4a.19   ch4fg.5_dac4a.19   CH4_logn1 ~ CH4_gen + CH4_ox
# 15   sem.ch4fg.7_dac4a.18   ch4fg.7_dac4a.18   CH4_logn1 ~ CH4_gen + CH4_ox
# 16   sem.ch4fg.9_dac4a.18   ch4fg.9_dac4a.18   CH4_logn1 ~ CH4_gen + CH4_ox
# 17   sem.ch4fg.8_dac4a.18   ch4fg.8_dac4a.18   CH4_logn1 ~ CH4_gen + CH4_ox
# 18   sem.ch4fg.6_dac4a.18   ch4fg.6_dac4a.18   CH4_logn1 ~ CH4_gen + CH4_ox
# 19   sem.ch4fg.3_dac4a.18   ch4fg.3_dac4a.18   CH4_logn1 ~ CH4_gen + CH4_ox
# 20   sem.ch4fg.10_dac4a.18  ch4fg.10_dac4a.18  CH4_logn1 ~ CH4_gen + CH4_ox
# 21   sem.ch4fg.5_dac4a.18   ch4fg.5_dac4a.18   CH4_logn1 ~ CH4_gen + CH4_ox
# 22   sem.ch4fg.7_dac4a.73   ch4fg.7_dac4a.73   CH4_logn1 ~ CH4_gen + CH4_ox
# 23   sem.ch4fg.9_dac4a.73   ch4fg.9_dac4a.73   CH4_logn1 ~ CH4_gen + CH4_ox
# 24   sem.ch4fg.8_dac4a.73   ch4fg.8_dac4a.73   CH4_logn1 ~ CH4_gen + CH4_ox
# 25   sem.ch4fg.6_dac4a.73   ch4fg.6_dac4a.73   CH4_logn1 ~ CH4_gen + CH4_ox
# 26   sem.ch4fg.3_dac4a.73   ch4fg.3_dac4a.73   CH4_logn1 ~ CH4_gen + CH4_ox
# 27   sem.ch4fg.10_dac4a.73  ch4fg.10_dac4a.73  CH4_logn1 ~ CH4_gen + CH4_ox
# 28   sem.ch4fg.5_dac4a.73   ch4fg.5_dac4a.73   CH4_logn1 ~ CH4_gen + CH4_ox
# 29   sem.ch4fg.7_dac4a.12   ch4fg.7_dac4a.12   CH4_logn1 ~ CH4_gen + CH4_ox
# 30   sem.ch4fg.9_dac4a.12   ch4fg.9_dac4a.12   CH4_logn1 ~ CH4_gen + CH4_ox
# ⋮    ⋮                      ⋮                  ⋮
# 993  sem.ch4fg.10_dac4a.196 ch4fg.10_dac4a.196 CH4_logn1 ~ CH4_gen + CH4_ox
# 994  sem.ch4fg.5_dac4a.196  ch4fg.5_dac4a.196  CH4_logn1 ~ CH4_gen + CH4_ox
# 995  sem.ch4fg.7_dac4a.175  ch4fg.7_dac4a.175  CH4_logn1 ~ CH4_gen + CH4_ox
# 996  sem.ch4fg.9_dac4a.175  ch4fg.9_dac4a.175  CH4_logn1 ~ CH4_gen + CH4_ox
# 997  sem.ch4fg.8_dac4a.175  ch4fg.8_dac4a.175  CH4_logn1 ~ CH4_gen + CH4_ox
# 998  sem.ch4fg.6_dac4a.175  ch4fg.6_dac4a.175  CH4_logn1 ~ CH4_gen + CH4_ox
# 999  sem.ch4fg.3_dac4a.175  ch4fg.3_dac4a.175  CH4_logn1 ~ CH4_gen + CH4_ox
# 1000 sem.ch4fg.10_dac4a.175 ch4fg.10_dac4a.175 CH4_logn1 ~ CH4_gen + CH4_ox
# 1001 sem.ch4fg.5_dac4a.175  ch4fg.5_dac4a.175  CH4_logn1 ~ CH4_gen + CH4_ox
# 1002 sem.ch4fg.7_dac4a.151  ch4fg.7_dac4a.151  CH4_logn1 ~ CH4_gen + CH4_ox
# 1003 sem.ch4fg.9_dac4a.151  ch4fg.9_dac4a.151  CH4_logn1 ~ CH4_gen + CH4_ox
# 1004 sem.ch4fg.8_dac4a.151  ch4fg.8_dac4a.151  CH4_logn1 ~ CH4_gen + CH4_ox
# 1005 sem.ch4fg.6_dac4a.151  ch4fg.6_dac4a.151  CH4_logn1 ~ CH4_gen + CH4_ox
# 1006 sem.ch4fg.3_dac4a.151  ch4fg.3_dac4a.151  CH4_logn1 ~ CH4_gen + CH4_ox
# 1007 sem.ch4fg.10_dac4a.151 ch4fg.10_dac4a.151 CH4_logn1 ~ CH4_gen + CH4_ox
# 1008 sem.ch4fg.5_dac4a.151  ch4fg.5_dac4a.151  CH4_logn1 ~ CH4_gen + CH4_ox
# 1009 sem.ch4fg.7_dac4a.86   ch4fg.7_dac4a.86   CH4_logn1 ~ CH4_gen + CH4_ox
# 1010 sem.ch4fg.9_dac4a.86   ch4fg.9_dac4a.86   CH4_logn1 ~ CH4_gen + CH4_ox
# 1011 sem.ch4fg.8_dac4a.86   ch4fg.8_dac4a.86   CH4_logn1 ~ CH4_gen + CH4_ox
# 1012 sem.ch4fg.6_dac4a.86   ch4fg.6_dac4a.86   CH4_logn1 ~ CH4_gen + CH4_ox
# 1013 sem.ch4fg.3_dac4a.86   ch4fg.3_dac4a.86   CH4_logn1 ~ CH4_gen + CH4_ox
# 1014 sem.ch4fg.10_dac4a.86  ch4fg.10_dac4a.86  CH4_logn1 ~ CH4_gen + CH4_ox
# 1015 sem.ch4fg.5_dac4a.86   ch4fg.5_dac4a.86   CH4_logn1 ~ CH4_gen + CH4_ox
# 1016 sem.ch4fg.7_dac4a.143  ch4fg.7_dac4a.143  CH4_logn1 ~ CH4_gen + CH4_ox
# 1017 sem.ch4fg.9_dac4a.143  ch4fg.9_dac4a.143  CH4_logn1 ~ CH4_gen + CH4_ox
# 1018 sem.ch4fg.8_dac4a.143  ch4fg.8_dac4a.143  CH4_logn1 ~ CH4_gen + CH4_ox
# 1019 sem.ch4fg.6_dac4a.143  ch4fg.6_dac4a.143  CH4_logn1 ~ CH4_gen + CH4_ox
# 1020 sem.ch4fg.3_dac4a.143  ch4fg.3_dac4a.143  CH4_logn1 ~ CH4_gen + CH4_ox
# 1021 sem.ch4fg.10_dac4a.143 ch4fg.10_dac4a.143 CH4_logn1 ~ CH4_gen + CH4_ox
# 1022 sem.ch4fg.5_dac4a.143  ch4fg.5_dac4a.143  CH4_logn1 ~ CH4_gen + CH4_ox
#      CH4_gen
# 1    CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + pH
# 2    CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4
# 3    CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 4    CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 5    CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 6    CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4
# 7    CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 8    CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + pH
# 9    CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4
# 10   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 11   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 12   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 13   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4
# 14   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 15   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + pH
# 16   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4
# 17   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 18   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 19   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 20   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4
# 21   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 22   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + pH
# 23   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4
# 24   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 25   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 26   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 27   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4
# 28   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 29   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + pH
# 30   CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4
# ⋮    ⋮
# 993  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4
# 994  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 995  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + pH
# 996  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4
# 997  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 998  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 999  CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 1000 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4
# 1001 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 1002 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + pH
# 1003 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4
# 1004 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 1005 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 1006 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 1007 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4
# 1008 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 1009 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + pH
# 1010 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4
# 1011 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 1012 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 1013 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 1014 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4
# 1015 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 1016 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + pH
# 1017 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4
# 1018 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 1019 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 1020 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
# 1021 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4
# 1022 CH4_gen <~ 1*CH4_ac + CO2_mg_m2_h
#      CH4_ox
# 1    CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 2    CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 3    CH4_ox <~ 1*MOB_IIa + Bulk_dens + AOB
# 4    CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 5    CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 6    CH4_ox <~ 1*MOB_IIa + H2O_FPS
# 7    CH4_ox <~ 1*MOB_IIa + AOB
# 8    CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 9    CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 10   CH4_ox <~ 1*MOB_IIa + Bulk_dens + AOB
# 11   CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 12   CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 13   CH4_ox <~ 1*MOB_IIa + H2O_FPS
# 14   CH4_ox <~ 1*MOB_IIa + AOB
# 15   CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 16   CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 17   CH4_ox <~ 1*MOB_IIa + Bulk_dens + AOB
# 18   CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 19   CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 20   CH4_ox <~ 1*MOB_IIa + H2O_FPS
# 21   CH4_ox <~ 1*MOB_IIa + AOB
# 22   CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 23   CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 24   CH4_ox <~ 1*MOB_IIa + Bulk_dens + AOB
# 25   CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 26   CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 27   CH4_ox <~ 1*MOB_IIa + H2O_FPS
# 28   CH4_ox <~ 1*MOB_IIa + AOB
# 29   CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 30   CH4_ox <~ 1*MOB_IIa + Bulk_dens
# ⋮    ⋮
# 993  CH4_ox <~ 1*MOB_IIa + H2O_FPS
# 994  CH4_ox <~ 1*MOB_IIa + AOB
# 995  CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 996  CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 997  CH4_ox <~ 1*MOB_IIa + Bulk_dens + AOB
# 998  CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 999  CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 1000 CH4_ox <~ 1*MOB_IIa + H2O_FPS
# 1001 CH4_ox <~ 1*MOB_IIa + AOB
# 1002 CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 1003 CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 1004 CH4_ox <~ 1*MOB_IIa + Bulk_dens + AOB
# 1005 CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 1006 CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 1007 CH4_ox <~ 1*MOB_IIa + H2O_FPS
# 1008 CH4_ox <~ 1*MOB_IIa + AOB
# 1009 CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 1010 CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 1011 CH4_ox <~ 1*MOB_IIa + Bulk_dens + AOB
# 1012 CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 1013 CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 1014 CH4_ox <~ 1*MOB_IIa + H2O_FPS
# 1015 CH4_ox <~ 1*MOB_IIa + AOB
# 1016 CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 1017 CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 1018 CH4_ox <~ 1*MOB_IIa + Bulk_dens + AOB
# 1019 CH4_ox <~ 1*MOB_IIa + Bulk_dens + N
# 1020 CH4_ox <~ 1*MOB_IIa + Bulk_dens
# 1021 CH4_ox <~ 1*MOB_IIa + H2O_FPS
# 1022 CH4_ox <~ 1*MOB_IIa + AOB
#      CH4_ac..
# 1    CH4_ac  ~ DOC_mg_L
# 2    CH4_ac  ~ DOC_mg_L
# 3    CH4_ac  ~ DOC_mg_L
# 4    CH4_ac  ~ DOC_mg_L
# 5    CH4_ac  ~ DOC_mg_L
# 6    CH4_ac  ~ DOC_mg_L
# 7    CH4_ac  ~ DOC_mg_L
# 8    CH4_ac  ~ DOC_mg_L + Fe_pw
# 9    CH4_ac  ~ DOC_mg_L + Fe_pw
# 10   CH4_ac  ~ DOC_mg_L + Fe_pw
# 11   CH4_ac  ~ DOC_mg_L + Fe_pw
# 12   CH4_ac  ~ DOC_mg_L + Fe_pw
# 13   CH4_ac  ~ DOC_mg_L + Fe_pw
# 14   CH4_ac  ~ DOC_mg_L + Fe_pw
# 15   CH4_ac  ~ DOC_mg_L + SRB_syn
# 16   CH4_ac  ~ DOC_mg_L + SRB_syn
# 17   CH4_ac  ~ DOC_mg_L + SRB_syn
# 18   CH4_ac  ~ DOC_mg_L + SRB_syn
# 19   CH4_ac  ~ DOC_mg_L + SRB_syn
# 20   CH4_ac  ~ DOC_mg_L + SRB_syn
# 21   CH4_ac  ~ DOC_mg_L + SRB_syn
# 22   CH4_ac  ~ DOC_mg_L + SRB_syn + Fe_pw
# 23   CH4_ac  ~ DOC_mg_L + SRB_syn + Fe_pw
# 24   CH4_ac  ~ DOC_mg_L + SRB_syn + Fe_pw
# 25   CH4_ac  ~ DOC_mg_L + SRB_syn + Fe_pw
# 26   CH4_ac  ~ DOC_mg_L + SRB_syn + Fe_pw
# 27   CH4_ac  ~ DOC_mg_L + SRB_syn + Fe_pw
# 28   CH4_ac  ~ DOC_mg_L + SRB_syn + Fe_pw
# 29   CH4_ac  ~ DOC_mg_L + CN
# 30   CH4_ac  ~ DOC_mg_L + CN
# ⋮    ⋮
# 993  CH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + pH + Fe_pw
# 994  CH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + pH + Fe_pw
# 995  CH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + pH + CN
# 996  CH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + pH + CN
# 997  CH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + pH + CN
# 998  CH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + pH + CN
# 999  CH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + pH + CN
# 1000 CH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + pH + CN
# 1001 CH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + pH + CN
# 1002 CH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + SO4
# 1003 CH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + SO4
# 1004 CH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + SO4
# 1005 CH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + SO4
# 1006 CH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + SO4
# 1007 CH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + SO4
# 1008 CH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + SO4
# 1009 CH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS
# 1010 CH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS
# 1011 CH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS
# 1012 CH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS
# 1013 CH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS
# 1014 CH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS
# 1015 CH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS
# 1016 CH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS + pH
# 1017 CH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS + pH
# 1018 CH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS + pH
# 1019 CH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS + pH
# 1020 CH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS + pH
# 1021 CH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS + pH
# 1022 CH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS + pH
#      formula
# 1    CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + pH\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ DOC_mg_L
# 2    CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ DOC_mg_L
# 3    CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + AOB\nCH4_ac  ~ DOC_mg_L
# 4    CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nCH4_ac  ~ DOC_mg_L
# 5    CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ DOC_mg_L
# 6    CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*MOB_IIa + H2O_FPS\nCH4_ac  ~ DOC_mg_L
# 7    CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + AOB\nCH4_ac  ~ DOC_mg_L
# 8    CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + pH\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ DOC_mg_L + Fe_pw
# 9    CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ DOC_mg_L + Fe_pw
# 10   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + AOB\nCH4_ac  ~ DOC_mg_L + Fe_pw
# 11   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nCH4_ac  ~ DOC_mg_L + Fe_pw
# 12   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ DOC_mg_L + Fe_pw
# 13   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*MOB_IIa + H2O_FPS\nCH4_ac  ~ DOC_mg_L + Fe_pw
# 14   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + AOB\nCH4_ac  ~ DOC_mg_L + Fe_pw
# 15   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + pH\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ DOC_mg_L + SRB_syn
# 16   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ DOC_mg_L + SRB_syn
# 17   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + AOB\nCH4_ac  ~ DOC_mg_L + SRB_syn
# 18   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nCH4_ac  ~ DOC_mg_L + SRB_syn
# 19   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ DOC_mg_L + SRB_syn
# 20   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*MOB_IIa + H2O_FPS\nCH4_ac  ~ DOC_mg_L + SRB_syn
# 21   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + AOB\nCH4_ac  ~ DOC_mg_L + SRB_syn
# 22   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + pH\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ DOC_mg_L + SRB_syn + Fe_pw
# 23   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ DOC_mg_L + SRB_syn + Fe_pw
# 24   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + AOB\nCH4_ac  ~ DOC_mg_L + SRB_syn + Fe_pw
# 25   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nCH4_ac  ~ DOC_mg_L + SRB_syn + Fe_pw
# 26   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ DOC_mg_L + SRB_syn + Fe_pw
# 27   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*MOB_IIa + H2O_FPS\nCH4_ac  ~ DOC_mg_L + SRB_syn + Fe_pw
# 28   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + AOB\nCH4_ac  ~ DOC_mg_L + SRB_syn + Fe_pw
# 29   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + pH\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ DOC_mg_L + CN
# 30   CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ DOC_mg_L + CN
# ⋮    ⋮
# 993  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*MOB_IIa + H2O_FPS\nCH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + pH + Fe_pw
# 994  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + AOB\nCH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + pH + Fe_pw
# 995  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + pH\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + pH + CN
# 996  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + pH + CN
# 997  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + AOB\nCH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + pH + CN
# 998  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nCH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + pH + CN
# 999  CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + pH + CN
# 1000 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*MOB_IIa + H2O_FPS\nCH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + pH + CN
# 1001 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + AOB\nCH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + pH + CN
# 1002 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + pH\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + SO4
# 1003 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + SO4
# 1004 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + AOB\nCH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + SO4
# 1005 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nCH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + SO4
# 1006 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + SO4
# 1007 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*MOB_IIa + H2O_FPS\nCH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + SO4
# 1008 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + AOB\nCH4_ac  ~ C + Salinity.x + Bulk_dens + SRB + SO4
# 1009 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + pH\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS
# 1010 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS
# 1011 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + AOB\nCH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS
# 1012 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nCH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS
# 1013 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS
# 1014 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*MOB_IIa + H2O_FPS\nCH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS
# 1015 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + AOB\nCH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS
# 1016 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + pH\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS + pH
# 1017 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS + pH
# 1018 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + AOB\nCH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS + pH
# 1019 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens + N\nCH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS + pH
# 1020 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + Bulk_dens\nCH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS + pH
# 1021 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h + SO4\nCH4_ox <~ 1*MOB_IIa + H2O_FPS\nCH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS + pH
# 1022 CH4_logn1 ~ CH4_gen + CH4_ox\nCH4_gen <~ 1*CH4_ac + CO2_mg_m2_h\nCH4_ox <~ 1*MOB_IIa + AOB\nCH4_ac  ~ C + Salinity.x + Bulk_dens + H2O_FPS + pH

# %%
# run simple delta models (4 min for 720? -- smaller data set) -- use SCALED dataset!! fails otherwise (& slower)!
# sem_run_test_d_ac <-run_sem_model_summary(sem_formula_tree_d, Guild_CH4_dS, sort_by = 'pvalue', sort_cutoff = 0.05) # pass parallel!!

# %%
#sem_run_test_d_ac

# %%
# filter results before printing
# sem_run_test_d_ac <- sem_run_test_d_ac[sem_run_test_d_ac$pvalue > 0.05,]

# %%
# write.table(sem_run_test_d_ac, "auto_tables/CH4f7_acf4a_delta_noClP_1022.txt", sep='\t', row.names=FALSE)
